# %% [markdown]
# # 03a_train_sarsa – Train SARSA
#
# **Chạy độc lập trên Kaggle.**
#
# Flow:
# 1. Setup
# 2. Load data
# 3. Train SARSA (500 episodes trên train stream)
# 4. Save pkl → `experiments/saved_models/sarsa.pkl`
# 5. Learning curve

# %%
#!git clone https://github.com/Briannguyen3106/RL-concept-drift.git
#%cd RL-concept-drift
#!pip install -r requirements.txt
# Out:
# Cloning into 'RL-concept-drift'...
# remote: Enumerating objects: 128, done.
# remote: Counting objects: 100% (128/128), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 128 (delta 45), reused 113 (delta 30), pack-reused 0 (from 0)
# Receiving objects: 100% (128/128), 11.44 MiB | 22.22 MiB/s, done.
# Resolving deltas: 100% (45/45), done.
# /kaggle/working/RL-concept-drift
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.4.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (2.3.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (1.6.1)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (4.6.0)
# Collecting mplcursors (from -r requirements.txt (line 7))
#   Downloading mplcursors-0.7.1-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 2)) (2026.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 3)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 3)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 3)) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 3)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 5)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 2)) (1.17.0)
# Downloading mplcursors-0.7.1-py3-none-any.whl (20 kB)
# Installing collected packages: mplcursors
# Successfully installed mplcursors-0.7.1

# %% [markdown]
# ## 1. Setup

# %%
import sys, os
import numpy as np
import pandas as pd

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

from config import FULL_WINDOW_BATCHES, BATCH_SIZE
from utils.data_loader import AirlinesDataLoader
from models.LightGBM import LightGBM
from metrics.stream_metrics import StreamMetrics
from environment.drift_env import DriftStreamEnv
from utils.visualizer import plot_cumulative_reward

SAVE_DIR = os.path.join(PROJECT_ROOT, 'RL-concept-drift', 'experiments', 'saved_models')
print('Setup complete!')
from agents.td_agent import SARSAAgent
# Out:
# Setup complete!

# %% [markdown]
# ## 2. Load Data

# %%
loader = AirlinesDataLoader()
X_train, y_train = loader.get_initial_train_data()

print(f'Train stream : {loader.n_train_batches} batches')
print(f'Test  stream : {loader.n_test_batches} batches')
# Out:
# [DataLoader] Loading data from: /kaggle/working/RL-concept-drift/data/Airlines.csv
# [DataLoader] Raw shape: (539383, 9)
# [DataLoader] 'Airline' → category dtype (18 unique values)
# [DataLoader] 'AirportFrom' → category dtype (293 unique values)
# [DataLoader] 'AirportTo' → category dtype (293 unique values)
# [DataLoader] Initial train size : 20,000
# [DataLoader] Stream size        : 519,383
# [DataLoader] Class distribution (train) – 0: 11,529 | 1: 8,471
# [DataLoader] Stream split → Train: 363 batches | Test: 156 batches
# Train stream : 363 batches
# Test  stream : 156 batches

# %% [markdown]
# ## 3. Setup Environment

# %%
clf     = LightGBM()
metrics = StreamMetrics()
env     = DriftStreamEnv(loader, clf, metrics)
print('Environment ready.')
# Out:
# Environment ready.

# %% [markdown]
# ## 4. Train SARSA
#
# - Epsilon cố định = 0.1 (không decay) – môi trường non-stationary
# - `mode='train'` → chỉ dùng train stream (70% đầu)
# - Mỗi episode bắt đầu từ `TD_EPISODE_STARTS` khác nhau để tránh học vẹt

# %%
N_EPISODES = 2000

agent = SARSAAgent()
print(f'Agent    : {agent.name}')
print(f'Epsilon  : {agent.epsilon} (fixed)')
print(f'Gamma    : {agent.gamma}')
print(f'Alpha    : {agent.alpha}')
print(f'Episodes : {N_EPISODES}')

history = agent.train(env, n_episodes=N_EPISODES, verbose=True)
# Out:
# Agent    : SARSAAgent
# Epsilon  : 0.1 (fixed)
# Gamma    : 0.9
# Alpha    : 0.1
# Episodes : 2000
#
# ============================================================
# Training TD Agent: SARSAAgent for 2000 episodes
# Fixed Epsilon: 0.1
# ============================================================
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode    1/2000 | Reward:   216.01 | Avg(10):   216.01 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode    2/2000 | Reward:   178.63 | Avg(10):   197.32 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode    3/2000 | Reward:   130.59 | Avg(10):   175.08 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode    4/2000 | Reward:    84.45 | Avg(10):   152.42 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode    5/2000 | Reward:    43.66 | Avg(10):   130.67 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode    6/2000 | Reward:   203.65 | Avg(10):   142.83 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode    7/2000 | Reward:   174.80 | Avg(10):   147.40 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode    8/2000 | Reward:   128.70 | Avg(10):   145.06 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode    9/2000 | Reward:    85.48 | Avg(10):   138.44 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   10/2000 | Reward:    41.50 | Avg(10):   128.75 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   11/2000 | Reward:   208.21 | Avg(10):   127.97 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   12/2000 | Reward:   151.49 | Avg(10):   125.25 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   13/2000 | Reward:   129.59 | Avg(10):   125.15 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   14/2000 | Reward:    84.16 | Avg(10):   125.12 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   15/2000 | Reward:    42.13 | Avg(10):   124.97 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   16/2000 | Reward:   191.21 | Avg(10):   123.73 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   17/2000 | Reward:   155.69 | Avg(10):   121.82 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   18/2000 | Reward:   124.09 | Avg(10):   121.35 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   19/2000 | Reward:    85.70 | Avg(10):   121.38 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   20/2000 | Reward:    42.63 | Avg(10):   121.49 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   21/2000 | Reward:   204.73 | Avg(10):   121.14 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   22/2000 | Reward:   146.39 | Avg(10):   120.63 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   23/2000 | Reward:   118.27 | Avg(10):   119.50 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   24/2000 | Reward:    86.25 | Avg(10):   119.71 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   25/2000 | Reward:    43.29 | Avg(10):   119.83 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   26/2000 | Reward:   208.53 | Avg(10):   121.56 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   27/2000 | Reward:   164.91 | Avg(10):   122.48 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   28/2000 | Reward:   123.68 | Avg(10):   122.44 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   29/2000 | Reward:    85.07 | Avg(10):   122.38 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   30/2000 | Reward:    44.00 | Avg(10):   122.51 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   31/2000 | Reward:   204.44 | Avg(10):   122.48 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   32/2000 | Reward:   172.81 | Avg(10):   125.12 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   33/2000 | Reward:   122.32 | Avg(10):   125.53 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   34/2000 | Reward:    86.81 | Avg(10):   125.59 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   35/2000 | Reward:    42.43 | Avg(10):   125.50 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   36/2000 | Reward:   222.11 | Avg(10):   126.86 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   37/2000 | Reward:   173.51 | Avg(10):   127.72 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   38/2000 | Reward:   127.89 | Avg(10):   128.14 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   39/2000 | Reward:    86.77 | Avg(10):   128.31 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   40/2000 | Reward:    41.72 | Avg(10):   128.08 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   41/2000 | Reward:   225.10 | Avg(10):   130.15 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   42/2000 | Reward:   170.98 | Avg(10):   129.96 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   43/2000 | Reward:   125.05 | Avg(10):   130.24 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   44/2000 | Reward:    86.54 | Avg(10):   130.21 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   45/2000 | Reward:    42.18 | Avg(10):   130.18 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   46/2000 | Reward:   203.97 | Avg(10):   128.37 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   47/2000 | Reward:   159.65 | Avg(10):   126.99 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   48/2000 | Reward:   129.92 | Avg(10):   127.19 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   49/2000 | Reward:    82.65 | Avg(10):   126.78 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   50/2000 | Reward:    42.40 | Avg(10):   126.84 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   51/2000 | Reward:   205.39 | Avg(10):   124.87 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   52/2000 | Reward:   175.25 | Avg(10):   125.30 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   53/2000 | Reward:   123.43 | Avg(10):   125.14 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   54/2000 | Reward:    88.67 | Avg(10):   125.35 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   55/2000 | Reward:    43.89 | Avg(10):   125.52 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   56/2000 | Reward:   228.23 | Avg(10):   127.95 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   57/2000 | Reward:   177.93 | Avg(10):   129.78 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   58/2000 | Reward:   132.50 | Avg(10):   130.04 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   59/2000 | Reward:    87.41 | Avg(10):   130.51 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   60/2000 | Reward:    43.32 | Avg(10):   130.60 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   61/2000 | Reward:   221.34 | Avg(10):   132.20 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   62/2000 | Reward:   179.61 | Avg(10):   132.63 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   63/2000 | Reward:   132.59 | Avg(10):   133.55 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   64/2000 | Reward:    88.72 | Avg(10):   133.56 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   65/2000 | Reward:    44.17 | Avg(10):   133.58 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   66/2000 | Reward:   224.43 | Avg(10):   133.20 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   67/2000 | Reward:   178.77 | Avg(10):   133.29 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   68/2000 | Reward:   133.18 | Avg(10):   133.35 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   69/2000 | Reward:    87.43 | Avg(10):   133.36 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   70/2000 | Reward:    44.31 | Avg(10):   133.45 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   71/2000 | Reward:   227.43 | Avg(10):   134.06 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   72/2000 | Reward:   180.72 | Avg(10):   134.17 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   73/2000 | Reward:   131.11 | Avg(10):   134.03 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   74/2000 | Reward:    88.96 | Avg(10):   134.05 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   75/2000 | Reward:    44.39 | Avg(10):   134.07 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   76/2000 | Reward:   225.62 | Avg(10):   134.19 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   77/2000 | Reward:   177.26 | Avg(10):   134.04 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   78/2000 | Reward:   134.00 | Avg(10):   134.12 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   79/2000 | Reward:    88.10 | Avg(10):   134.19 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   80/2000 | Reward:    44.27 | Avg(10):   134.19 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   81/2000 | Reward:   217.60 | Avg(10):   133.20 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   82/2000 | Reward:   170.08 | Avg(10):   132.14 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   83/2000 | Reward:   134.06 | Avg(10):   132.43 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   84/2000 | Reward:    91.27 | Avg(10):   132.66 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   85/2000 | Reward:    44.18 | Avg(10):   132.64 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   86/2000 | Reward:   208.38 | Avg(10):   130.92 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   87/2000 | Reward:   158.70 | Avg(10):   129.06 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   88/2000 | Reward:   131.92 | Avg(10):   128.86 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   89/2000 | Reward:    88.28 | Avg(10):   128.87 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   90/2000 | Reward:    43.86 | Avg(10):   128.83 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   91/2000 | Reward:   208.66 | Avg(10):   127.94 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   92/2000 | Reward:   176.46 | Avg(10):   128.58 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   93/2000 | Reward:   128.09 | Avg(10):   127.98 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   94/2000 | Reward:    89.40 | Avg(10):   127.79 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   95/2000 | Reward:    43.60 | Avg(10):   127.74 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   96/2000 | Reward:   227.20 | Avg(10):   129.62 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   97/2000 | Reward:   176.96 | Avg(10):   131.44 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   98/2000 | Reward:   131.56 | Avg(10):   131.41 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   99/2000 | Reward:    85.90 | Avg(10):   131.17 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  100/2000 | Reward:    43.24 | Avg(10):   131.11 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  101/2000 | Reward:   223.95 | Avg(10):   132.64 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  102/2000 | Reward:   165.78 | Avg(10):   131.57 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  103/2000 | Reward:   127.65 | Avg(10):   131.52 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  104/2000 | Reward:    86.96 | Avg(10):   131.28 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  105/2000 | Reward:    42.98 | Avg(10):   131.22 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  106/2000 | Reward:   189.03 | Avg(10):   127.40 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  107/2000 | Reward:   175.33 | Avg(10):   127.24 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  108/2000 | Reward:   131.97 | Avg(10):   127.28 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  109/2000 | Reward:    86.97 | Avg(10):   127.39 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  110/2000 | Reward:    42.73 | Avg(10):   127.33 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  111/2000 | Reward:   209.25 | Avg(10):   125.86 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  112/2000 | Reward:   174.21 | Avg(10):   126.71 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  113/2000 | Reward:   128.89 | Avg(10):   126.83 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  114/2000 | Reward:    86.23 | Avg(10):   126.76 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  115/2000 | Reward:    43.07 | Avg(10):   126.77 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  116/2000 | Reward:   192.51 | Avg(10):   127.12 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  117/2000 | Reward:   173.91 | Avg(10):   126.98 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  118/2000 | Reward:   129.69 | Avg(10):   126.75 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  119/2000 | Reward:    86.54 | Avg(10):   126.70 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  120/2000 | Reward:    43.98 | Avg(10):   126.83 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  121/2000 | Reward:   219.03 | Avg(10):   127.81 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  122/2000 | Reward:   176.55 | Avg(10):   128.04 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  123/2000 | Reward:   132.75 | Avg(10):   128.43 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  124/2000 | Reward:    86.87 | Avg(10):   128.49 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  125/2000 | Reward:    44.50 | Avg(10):   128.63 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  126/2000 | Reward:   224.97 | Avg(10):   131.88 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  127/2000 | Reward:   150.26 | Avg(10):   129.51 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  128/2000 | Reward:   133.31 | Avg(10):   129.88 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  129/2000 | Reward:    87.93 | Avg(10):   130.01 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  130/2000 | Reward:    44.09 | Avg(10):   130.02 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  131/2000 | Reward:   224.27 | Avg(10):   130.55 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  132/2000 | Reward:   152.60 | Avg(10):   128.15 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  133/2000 | Reward:   130.65 | Avg(10):   127.94 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  134/2000 | Reward:    89.01 | Avg(10):   128.16 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  135/2000 | Reward:    44.26 | Avg(10):   128.13 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  136/2000 | Reward:   219.26 | Avg(10):   127.56 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  137/2000 | Reward:   174.67 | Avg(10):   130.00 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  138/2000 | Reward:   132.28 | Avg(10):   129.90 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  139/2000 | Reward:    88.73 | Avg(10):   129.98 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  140/2000 | Reward:    44.11 | Avg(10):   129.98 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  141/2000 | Reward:   206.43 | Avg(10):   128.20 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  142/2000 | Reward:   177.83 | Avg(10):   130.72 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  143/2000 | Reward:   133.32 | Avg(10):   130.99 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  144/2000 | Reward:    88.49 | Avg(10):   130.94 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  145/2000 | Reward:    44.48 | Avg(10):   130.96 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  146/2000 | Reward:   208.59 | Avg(10):   129.89 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  147/2000 | Reward:   179.65 | Avg(10):   130.39 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  148/2000 | Reward:   131.83 | Avg(10):   130.35 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  149/2000 | Reward:    88.62 | Avg(10):   130.33 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  150/2000 | Reward:    44.11 | Avg(10):   130.33 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  151/2000 | Reward:   206.68 | Avg(10):   130.36 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  152/2000 | Reward:   175.52 | Avg(10):   130.13 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  153/2000 | Reward:   134.12 | Avg(10):   130.21 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  154/2000 | Reward:    89.10 | Avg(10):   130.27 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  155/2000 | Reward:    43.83 | Avg(10):   130.21 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  156/2000 | Reward:   226.63 | Avg(10):   132.01 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  157/2000 | Reward:   142.57 | Avg(10):   128.30 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  158/2000 | Reward:   132.15 | Avg(10):   128.33 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  159/2000 | Reward:    88.24 | Avg(10):   128.30 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  160/2000 | Reward:    44.27 | Avg(10):   128.31 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  161/2000 | Reward:   225.93 | Avg(10):   130.24 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  162/2000 | Reward:   149.35 | Avg(10):   127.62 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  163/2000 | Reward:   112.75 | Avg(10):   125.48 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  164/2000 | Reward:    89.05 | Avg(10):   125.48 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  165/2000 | Reward:    44.45 | Avg(10):   125.54 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  166/2000 | Reward:   219.51 | Avg(10):   124.83 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  167/2000 | Reward:   175.98 | Avg(10):   128.17 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  168/2000 | Reward:   131.20 | Avg(10):   128.07 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  169/2000 | Reward:    86.72 | Avg(10):   127.92 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  170/2000 | Reward:    43.34 | Avg(10):   127.83 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  171/2000 | Reward:   223.83 | Avg(10):   127.62 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  172/2000 | Reward:   157.71 | Avg(10):   128.45 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  173/2000 | Reward:   132.57 | Avg(10):   130.44 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  174/2000 | Reward:    87.17 | Avg(10):   130.25 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  175/2000 | Reward:    43.86 | Avg(10):   130.19 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  176/2000 | Reward:   225.92 | Avg(10):   130.83 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  177/2000 | Reward:   177.16 | Avg(10):   130.95 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  178/2000 | Reward:   131.10 | Avg(10):   130.94 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  179/2000 | Reward:    86.59 | Avg(10):   130.93 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  180/2000 | Reward:    43.81 | Avg(10):   130.97 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  181/2000 | Reward:   191.33 | Avg(10):   127.72 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  182/2000 | Reward:   176.25 | Avg(10):   129.58 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  183/2000 | Reward:   102.90 | Avg(10):   126.61 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  184/2000 | Reward:    69.31 | Avg(10):   124.82 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  185/2000 | Reward:    42.60 | Avg(10):   124.70 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  186/2000 | Reward:   188.29 | Avg(10):   120.93 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  187/2000 | Reward:   166.58 | Avg(10):   119.88 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  188/2000 | Reward:   131.21 | Avg(10):   119.89 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  189/2000 | Reward:    85.97 | Avg(10):   119.82 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  190/2000 | Reward:    44.30 | Avg(10):   119.87 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  191/2000 | Reward:   226.39 | Avg(10):   123.38 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  192/2000 | Reward:   179.66 | Avg(10):   123.72 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  193/2000 | Reward:   133.48 | Avg(10):   126.78 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  194/2000 | Reward:    89.68 | Avg(10):   128.82 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  195/2000 | Reward:    44.33 | Avg(10):   128.99 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  196/2000 | Reward:   223.97 | Avg(10):   132.56 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  197/2000 | Reward:   158.02 | Avg(10):   131.70 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  198/2000 | Reward:   128.47 | Avg(10):   131.43 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  199/2000 | Reward:    88.92 | Avg(10):   131.72 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  200/2000 | Reward:    43.87 | Avg(10):   131.68 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  201/2000 | Reward:   226.06 | Avg(10):   131.65 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  202/2000 | Reward:   177.78 | Avg(10):   131.46 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  203/2000 | Reward:   129.31 | Avg(10):   131.04 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  204/2000 | Reward:    81.88 | Avg(10):   130.26 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  205/2000 | Reward:    43.69 | Avg(10):   130.20 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  206/2000 | Reward:   220.77 | Avg(10):   129.88 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  207/2000 | Reward:   176.73 | Avg(10):   131.75 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  208/2000 | Reward:   131.43 | Avg(10):   132.05 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  209/2000 | Reward:    86.25 | Avg(10):   131.78 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  210/2000 | Reward:    43.98 | Avg(10):   131.79 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  211/2000 | Reward:   223.64 | Avg(10):   131.55 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  212/2000 | Reward:   175.86 | Avg(10):   131.35 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  213/2000 | Reward:   128.52 | Avg(10):   131.27 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  214/2000 | Reward:    87.74 | Avg(10):   131.86 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  215/2000 | Reward:    43.64 | Avg(10):   131.85 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  216/2000 | Reward:   205.57 | Avg(10):   130.33 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  217/2000 | Reward:   175.80 | Avg(10):   130.24 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  218/2000 | Reward:   129.88 | Avg(10):   130.09 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  219/2000 | Reward:    86.38 | Avg(10):   130.10 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  220/2000 | Reward:    43.23 | Avg(10):   130.02 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  221/2000 | Reward:   223.64 | Avg(10):   130.03 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  222/2000 | Reward:   178.50 | Avg(10):   130.29 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  223/2000 | Reward:   133.11 | Avg(10):   130.75 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  224/2000 | Reward:    88.26 | Avg(10):   130.80 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  225/2000 | Reward:    43.46 | Avg(10):   130.78 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  226/2000 | Reward:   226.03 | Avg(10):   132.83 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  227/2000 | Reward:   177.99 | Avg(10):   133.05 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  228/2000 | Reward:   133.25 | Avg(10):   133.38 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  229/2000 | Reward:    85.40 | Avg(10):   133.29 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  230/2000 | Reward:    44.28 | Avg(10):   133.39 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  231/2000 | Reward:   204.69 | Avg(10):   131.50 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  232/2000 | Reward:   152.03 | Avg(10):   128.85 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  233/2000 | Reward:   126.72 | Avg(10):   128.21 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  234/2000 | Reward:    86.71 | Avg(10):   128.06 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  235/2000 | Reward:    42.44 | Avg(10):   127.95 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  236/2000 | Reward:   222.19 | Avg(10):   127.57 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  237/2000 | Reward:   176.71 | Avg(10):   127.44 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  238/2000 | Reward:   126.45 | Avg(10):   126.76 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  239/2000 | Reward:    90.51 | Avg(10):   127.27 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  240/2000 | Reward:    44.37 | Avg(10):   127.28 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  241/2000 | Reward:   190.99 | Avg(10):   125.91 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  242/2000 | Reward:   144.96 | Avg(10):   125.21 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  243/2000 | Reward:   129.77 | Avg(10):   125.51 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  244/2000 | Reward:    87.03 | Avg(10):   125.54 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  245/2000 | Reward:    42.47 | Avg(10):   125.55 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  246/2000 | Reward:   207.07 | Avg(10):   124.03 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  247/2000 | Reward:   149.22 | Avg(10):   121.28 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  248/2000 | Reward:   128.96 | Avg(10):   121.54 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  249/2000 | Reward:    84.99 | Avg(10):   120.98 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  250/2000 | Reward:    44.29 | Avg(10):   120.97 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  251/2000 | Reward:   214.88 | Avg(10):   123.36 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  252/2000 | Reward:   163.22 | Avg(10):   125.19 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  253/2000 | Reward:   132.97 | Avg(10):   125.51 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  254/2000 | Reward:    88.11 | Avg(10):   125.62 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  255/2000 | Reward:    43.77 | Avg(10):   125.75 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  256/2000 | Reward:   205.17 | Avg(10):   125.56 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  257/2000 | Reward:   172.70 | Avg(10):   127.90 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  258/2000 | Reward:   133.40 | Avg(10):   128.35 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  259/2000 | Reward:    88.12 | Avg(10):   128.66 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  260/2000 | Reward:    44.30 | Avg(10):   128.66 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  261/2000 | Reward:   228.32 | Avg(10):   130.01 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  262/2000 | Reward:   172.88 | Avg(10):   130.97 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  263/2000 | Reward:   130.46 | Avg(10):   130.72 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  264/2000 | Reward:    88.40 | Avg(10):   130.75 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  265/2000 | Reward:    44.26 | Avg(10):   130.80 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  266/2000 | Reward:   225.97 | Avg(10):   132.88 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  267/2000 | Reward:   178.26 | Avg(10):   133.44 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  268/2000 | Reward:   132.46 | Avg(10):   133.34 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  269/2000 | Reward:    87.97 | Avg(10):   133.33 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  270/2000 | Reward:    44.38 | Avg(10):   133.34 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  271/2000 | Reward:   225.87 | Avg(10):   133.09 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  272/2000 | Reward:   179.00 | Avg(10):   133.70 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  273/2000 | Reward:   132.64 | Avg(10):   133.92 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  274/2000 | Reward:    88.30 | Avg(10):   133.91 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  275/2000 | Reward:    43.75 | Avg(10):   133.86 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  276/2000 | Reward:   225.14 | Avg(10):   133.78 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  277/2000 | Reward:   173.39 | Avg(10):   133.29 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  278/2000 | Reward:   132.73 | Avg(10):   133.32 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  279/2000 | Reward:    86.17 | Avg(10):   133.14 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  280/2000 | Reward:    44.12 | Avg(10):   133.11 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  281/2000 | Reward:   224.60 | Avg(10):   132.98 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  282/2000 | Reward:   179.19 | Avg(10):   133.00 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  283/2000 | Reward:   125.65 | Avg(10):   132.30 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  284/2000 | Reward:    87.76 | Avg(10):   132.25 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  285/2000 | Reward:    43.98 | Avg(10):   132.27 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  286/2000 | Reward:   217.24 | Avg(10):   131.48 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  287/2000 | Reward:   167.99 | Avg(10):   130.94 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  288/2000 | Reward:   132.62 | Avg(10):   130.93 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  289/2000 | Reward:    88.85 | Avg(10):   131.20 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  290/2000 | Reward:    44.08 | Avg(10):   131.19 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  291/2000 | Reward:   216.49 | Avg(10):   130.38 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  292/2000 | Reward:   164.16 | Avg(10):   128.88 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  293/2000 | Reward:   131.29 | Avg(10):   129.45 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  294/2000 | Reward:    88.65 | Avg(10):   129.53 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  295/2000 | Reward:    44.18 | Avg(10):   129.55 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  296/2000 | Reward:   213.74 | Avg(10):   129.20 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  297/2000 | Reward:   177.48 | Avg(10):   130.15 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  298/2000 | Reward:   129.81 | Avg(10):   129.87 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  299/2000 | Reward:    88.29 | Avg(10):   129.82 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  300/2000 | Reward:    43.99 | Avg(10):   129.81 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  301/2000 | Reward:   225.26 | Avg(10):   130.68 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  302/2000 | Reward:   164.12 | Avg(10):   130.68 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  303/2000 | Reward:   133.48 | Avg(10):   130.90 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  304/2000 | Reward:    88.71 | Avg(10):   130.91 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  305/2000 | Reward:    44.06 | Avg(10):   130.89 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  306/2000 | Reward:   220.47 | Avg(10):   131.57 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  307/2000 | Reward:   155.23 | Avg(10):   129.34 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  308/2000 | Reward:   127.21 | Avg(10):   129.08 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  309/2000 | Reward:    88.95 | Avg(10):   129.15 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  310/2000 | Reward:    44.27 | Avg(10):   129.18 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  311/2000 | Reward:   223.29 | Avg(10):   128.98 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  312/2000 | Reward:   157.10 | Avg(10):   128.28 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  313/2000 | Reward:   129.43 | Avg(10):   127.87 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  314/2000 | Reward:    85.91 | Avg(10):   127.59 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  315/2000 | Reward:    42.13 | Avg(10):   127.40 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  316/2000 | Reward:   220.06 | Avg(10):   127.36 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  317/2000 | Reward:   153.78 | Avg(10):   127.21 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  318/2000 | Reward:   124.80 | Avg(10):   126.97 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  319/2000 | Reward:    88.12 | Avg(10):   126.89 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  320/2000 | Reward:    43.28 | Avg(10):   126.79 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  321/2000 | Reward:   225.50 | Avg(10):   127.01 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  322/2000 | Reward:   163.66 | Avg(10):   127.67 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  323/2000 | Reward:   129.53 | Avg(10):   127.68 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  324/2000 | Reward:    86.28 | Avg(10):   127.71 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  325/2000 | Reward:    44.17 | Avg(10):   127.92 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  326/2000 | Reward:   210.91 | Avg(10):   127.00 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# ...
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1892/2000 | Reward:   173.30 | Avg(10):   132.01 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1893/2000 | Reward:   133.26 | Avg(10):   132.73 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1894/2000 | Reward:    88.13 | Avg(10):   132.75 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1895/2000 | Reward:    43.85 | Avg(10):   132.68 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1896/2000 | Reward:   225.91 | Avg(10):   133.01 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1897/2000 | Reward:   177.60 | Avg(10):   133.59 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1898/2000 | Reward:   132.52 | Avg(10):   133.51 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1899/2000 | Reward:    79.41 | Avg(10):   132.54 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1900/2000 | Reward:    44.27 | Avg(10):   132.55 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1901/2000 | Reward:   227.33 | Avg(10):   132.56 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1902/2000 | Reward:   163.88 | Avg(10):   131.61 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1903/2000 | Reward:   131.65 | Avg(10):   131.45 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1904/2000 | Reward:    88.53 | Avg(10):   131.49 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1905/2000 | Reward:    44.08 | Avg(10):   131.52 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1906/2000 | Reward:   228.92 | Avg(10):   131.82 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1907/2000 | Reward:   162.44 | Avg(10):   130.30 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1908/2000 | Reward:   132.91 | Avg(10):   130.34 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1909/2000 | Reward:    87.33 | Avg(10):   131.13 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1910/2000 | Reward:    44.38 | Avg(10):   131.15 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1911/2000 | Reward:   223.10 | Avg(10):   130.72 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1912/2000 | Reward:   160.65 | Avg(10):   130.40 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1913/2000 | Reward:   133.08 | Avg(10):   130.54 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1914/2000 | Reward:    88.03 | Avg(10):   130.49 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1915/2000 | Reward:    44.56 | Avg(10):   130.54 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1916/2000 | Reward:   223.58 | Avg(10):   130.01 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1917/2000 | Reward:   165.95 | Avg(10):   130.36 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1918/2000 | Reward:   130.91 | Avg(10):   130.16 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1919/2000 | Reward:    85.60 | Avg(10):   129.98 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1920/2000 | Reward:    43.89 | Avg(10):   129.94 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1921/2000 | Reward:   220.58 | Avg(10):   129.68 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1922/2000 | Reward:   171.17 | Avg(10):   130.73 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1923/2000 | Reward:   133.25 | Avg(10):   130.75 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1924/2000 | Reward:    89.02 | Avg(10):   130.85 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1925/2000 | Reward:    38.22 | Avg(10):   130.22 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1926/2000 | Reward:   215.38 | Avg(10):   129.40 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1927/2000 | Reward:   175.96 | Avg(10):   130.40 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1928/2000 | Reward:   134.84 | Avg(10):   130.79 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1929/2000 | Reward:    87.32 | Avg(10):   130.96 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1930/2000 | Reward:    43.31 | Avg(10):   130.90 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1931/2000 | Reward:   224.39 | Avg(10):   131.29 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1932/2000 | Reward:   162.09 | Avg(10):   130.38 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1933/2000 | Reward:   131.96 | Avg(10):   130.25 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1934/2000 | Reward:    88.78 | Avg(10):   130.22 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1935/2000 | Reward:    44.32 | Avg(10):   130.83 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1936/2000 | Reward:   225.57 | Avg(10):   131.85 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1937/2000 | Reward:   171.44 | Avg(10):   131.40 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1938/2000 | Reward:   130.45 | Avg(10):   130.96 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1939/2000 | Reward:    87.60 | Avg(10):   130.99 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1940/2000 | Reward:    43.82 | Avg(10):   131.04 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1941/2000 | Reward:   228.54 | Avg(10):   131.46 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1942/2000 | Reward:   170.02 | Avg(10):   132.25 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1943/2000 | Reward:   130.95 | Avg(10):   132.15 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1944/2000 | Reward:    88.42 | Avg(10):   132.11 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1945/2000 | Reward:    43.97 | Avg(10):   132.08 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1946/2000 | Reward:   224.80 | Avg(10):   132.00 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1947/2000 | Reward:   172.09 | Avg(10):   132.07 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1948/2000 | Reward:   128.72 | Avg(10):   131.89 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1949/2000 | Reward:    87.04 | Avg(10):   131.84 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1950/2000 | Reward:    44.31 | Avg(10):   131.89 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1951/2000 | Reward:   213.01 | Avg(10):   130.33 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1952/2000 | Reward:   163.71 | Avg(10):   129.70 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1953/2000 | Reward:   129.15 | Avg(10):   129.52 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1954/2000 | Reward:    88.06 | Avg(10):   129.49 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1955/2000 | Reward:    43.18 | Avg(10):   129.41 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1956/2000 | Reward:   211.65 | Avg(10):   128.09 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1957/2000 | Reward:   179.29 | Avg(10):   128.81 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1958/2000 | Reward:   133.65 | Avg(10):   129.30 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1959/2000 | Reward:    88.42 | Avg(10):   129.44 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1960/2000 | Reward:    36.92 | Avg(10):   128.70 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1961/2000 | Reward:   223.54 | Avg(10):   129.76 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1962/2000 | Reward:   163.44 | Avg(10):   129.73 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1963/2000 | Reward:   133.38 | Avg(10):   130.15 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1964/2000 | Reward:    88.02 | Avg(10):   130.15 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1965/2000 | Reward:    44.00 | Avg(10):   130.23 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1966/2000 | Reward:   225.76 | Avg(10):   131.64 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1967/2000 | Reward:   175.02 | Avg(10):   131.21 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1968/2000 | Reward:   130.91 | Avg(10):   130.94 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1969/2000 | Reward:    86.95 | Avg(10):   130.79 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1970/2000 | Reward:    43.60 | Avg(10):   131.46 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1971/2000 | Reward:   230.01 | Avg(10):   132.11 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1972/2000 | Reward:   170.16 | Avg(10):   132.78 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1973/2000 | Reward:   130.27 | Avg(10):   132.47 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1974/2000 | Reward:    88.71 | Avg(10):   132.54 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1975/2000 | Reward:    44.19 | Avg(10):   132.56 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1976/2000 | Reward:   228.44 | Avg(10):   132.83 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1977/2000 | Reward:   166.32 | Avg(10):   131.95 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1978/2000 | Reward:   132.29 | Avg(10):   132.09 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1979/2000 | Reward:    87.58 | Avg(10):   132.16 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1980/2000 | Reward:    44.50 | Avg(10):   132.25 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1981/2000 | Reward:   223.31 | Avg(10):   131.58 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1982/2000 | Reward:   161.50 | Avg(10):   130.71 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1983/2000 | Reward:   128.31 | Avg(10):   130.51 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1984/2000 | Reward:    88.96 | Avg(10):   130.54 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1985/2000 | Reward:    44.39 | Avg(10):   130.56 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1986/2000 | Reward:   227.98 | Avg(10):   130.51 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1987/2000 | Reward:   159.45 | Avg(10):   129.83 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1988/2000 | Reward:   133.57 | Avg(10):   129.96 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1989/2000 | Reward:    88.70 | Avg(10):   130.07 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1990/2000 | Reward:    45.04 | Avg(10):   130.12 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1991/2000 | Reward:   207.80 | Avg(10):   128.57 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1992/2000 | Reward:   167.93 | Avg(10):   129.21 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1993/2000 | Reward:   132.54 | Avg(10):   129.64 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1994/2000 | Reward:    88.77 | Avg(10):   129.62 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1995/2000 | Reward:    43.84 | Avg(10):   129.56 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1996/2000 | Reward:   215.08 | Avg(10):   128.27 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1997/2000 | Reward:   176.17 | Avg(10):   129.94 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1998/2000 | Reward:   134.37 | Avg(10):   130.02 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1999/2000 | Reward:    89.16 | Avg(10):   130.07 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 2000/2000 | Reward:    44.06 | Avg(10):   129.97 | Steps:   72
#
# [SARSAAgent] Training complete!

# %% [markdown]
# ## 5. Save Agent

# %%
save_path = os.path.join(SAVE_DIR, 'sarsa.pkl')
agent.save(save_path)
print(f'Saved → {save_path}')
print(f'States visited : {len(agent.Q)}')
# Out:
# [SARSAAgent] Saved → /kaggle/working/RL-concept-drift/experiments/saved_models/sarsa.pkl
# Saved → /kaggle/working/RL-concept-drift/experiments/saved_models/sarsa.pkl
# States visited : 249

# %% [markdown]
# ## 6. Learning Curve

# %%
rewards = history['episode_rewards']
print(f'Avg reward (all)    : {np.mean(rewards):.4f}')
print(f'Avg reward (last 10): {np.mean(rewards[-10:]):.4f}')
print(f'Best episode reward : {max(rewards):.4f}')
print(f'Action distribution : {history["action_counts"]}')

plot_cumulative_reward(
    {'SARSA': rewards},
    title    = 'SARSA – Episode Reward over Training (Train Stream)',
    filename = 'sarsa_learning_curve.png',
)
# Out:
# Avg reward (all)    : 129.8810
# Avg reward (last 10): 129.9723
# Best episode reward : 230.0090
# Action distribution : {'no_action': 152293, 'partial_update': 21794, 'full_retrain': 12893, 'alert': 116343, 'switch_model': 132277}
# [Visualizer] Saved → /kaggle/working/RL-concept-drift/experiments/results/sarsa_learning_curve.png

# %% [markdown]
# ## 7. Quick Sanity Check – Greedy Policy

# %%
# Set epsilon = 0.0 → pure greedy để kiểm tra policy đã học
agent.epsilon = 0.0
print(f'Top 10 states by Q-value spread:')
items = sorted(
    agent.Q.items(),
    key=lambda x: np.max(x[1]) - np.min(x[1]),
    reverse=True
)[:10]
for state, q in items:
    best_action = int(np.argmax(q))
    from environment.drift_env import ACTIONS
    print(f'  {state} → {ACTIONS[best_action]:<16} Q={np.round(q,3)}')

# Restore epsilon
agent.epsilon = 0.1
# Out:
# Top 10 states by Q-value spread:
#   (0, 0, 3, 1, 1) → no_action        Q=[6.057 0.    2.629 2.99  1.538]
#   (1, 1, 1, 2, 0) → no_action        Q=[5.825 0.    0.515 1.402 1.141]
#   (0, 0, 3, 0, 0) → no_action        Q=[5.785 0.    0.512 0.    1.162]
#   (0, 0, 0, 0, 0) → no_action        Q=[6.339 0.605 0.566 0.609 1.111]
#   (1, 2, 2, 1, 0) → no_action        Q=[5.745 0.825 1.14  1.098 0.   ]
#   (1, 1, 1, 1, 0) → no_action        Q=[5.677 0.5   0.    0.604 0.584]
#   (2, 1, 1, 1, 0) → no_action        Q=[5.65  1.546 1.033 1.753 0.   ]
#   (1, 1, 2, 1, 0) → no_action        Q=[5.604 0.    0.    0.507 0.979]
#   (2, 1, 2, 1, 0) → switch_model     Q=[0.123 0.    0.    0.491 5.541]
#   (1, 0, 0, 0, 0) → no_action        Q=[6.027 2.203 1.825 0.605 2.446]
