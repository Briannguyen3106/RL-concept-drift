# %% [markdown]
# # 03c_train_qlearning – Train Q-Learning
#
# **Chạy độc lập trên Kaggle.**
#
# Flow:
# 1. Setup
# 2. Load data
# 3. Train Q-Learning (500 episodes trên train stream)
# 4. Save pkl → `experiments/saved_models/qlearning.pkl`
# 5. Learning curve

# %% [markdown]
# ## 1. Setup

# %%
#!git clone https://github.com/Briannguyen3106/RL-concept-drift.git
#%cd RL-concept-drift
#!pip install -r requirements.txt
# Out:
# Cloning into 'RL-concept-drift'...
# remote: Enumerating objects: 128, done.
# remote: Counting objects: 100% (128/128), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 128 (delta 45), reused 113 (delta 30), pack-reused 0 (from 0)
# Receiving objects: 100% (128/128), 11.44 MiB | 20.05 MiB/s, done.
# Resolving deltas: 100% (45/45), done.
# /kaggle/working/RL-concept-drift
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.4.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (2.3.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (1.6.1)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (4.6.0)
# Collecting mplcursors (from -r requirements.txt (line 7))
#   Downloading mplcursors-0.7.1-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 2)) (2026.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 3)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 3)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 3)) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 3)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 5)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 2)) (1.17.0)
# Downloading mplcursors-0.7.1-py3-none-any.whl (20 kB)
# Installing collected packages: mplcursors
# Successfully installed mplcursors-0.7.1

# %%
import sys, os
import numpy as np
import pandas as pd

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

from config import FULL_WINDOW_BATCHES, BATCH_SIZE
from utils.data_loader import AirlinesDataLoader
from models.LightGBM import LightGBM
from metrics.stream_metrics import StreamMetrics
from environment.drift_env import DriftStreamEnv
from utils.visualizer import plot_cumulative_reward

SAVE_DIR = os.path.join(PROJECT_ROOT, 'RL-concept-drift', 'experiments', 'saved_models')
print('Setup complete!')
from agents.td_agent import QLearningAgent
# Out:
# Setup complete!

# %% [markdown]
# ## 2. Load Data

# %%
loader = AirlinesDataLoader()
X_train, y_train = loader.get_initial_train_data()

print(f'Train stream : {loader.n_train_batches} batches')
print(f'Test  stream : {loader.n_test_batches} batches')
# Out:
# [DataLoader] Loading data from: /kaggle/working/RL-concept-drift/data/Airlines.csv
# [DataLoader] Raw shape: (539383, 9)
# [DataLoader] 'Airline' → category dtype (18 unique values)
# [DataLoader] 'AirportFrom' → category dtype (293 unique values)
# [DataLoader] 'AirportTo' → category dtype (293 unique values)
# [DataLoader] Initial train size : 20,000
# [DataLoader] Stream size        : 519,383
# [DataLoader] Class distribution (train) – 0: 11,529 | 1: 8,471
# [DataLoader] Stream split → Train: 363 batches | Test: 156 batches
# Train stream : 363 batches
# Test  stream : 156 batches

# %% [markdown]
# ## 3. Setup Environment

# %%
clf     = LightGBM()
metrics = StreamMetrics()
env     = DriftStreamEnv(loader, clf, metrics)
print('Environment ready.')
# Out:
# Environment ready.

# %% [markdown]
# ## 4. Train Q-Learning
#
# - Epsilon cố định = 0.1 (không decay) – môi trường non-stationary
# - `mode='train'` → chỉ dùng train stream (70% đầu)
# - Mỗi episode bắt đầu từ `TD_EPISODE_STARTS` khác nhau để tránh học vẹt

# %%
N_EPISODES = 2000

agent = QLearningAgent()
print(f'Agent    : {agent.name}')
print(f'Epsilon  : {agent.epsilon} (fixed)')
print(f'Gamma    : {agent.gamma}')
print(f'Alpha    : {agent.alpha}')
print(f'Episodes : {N_EPISODES}')

history = agent.train(env, n_episodes=N_EPISODES, verbose=True)
# Out:
# Agent    : QLearningAgent
# Epsilon  : 0.1 (fixed)
# Gamma    : 0.9
# Alpha    : 0.1
# Episodes : 2000
#
# ============================================================
# Training TD Agent: QLearningAgent for 2000 episodes
# Fixed Epsilon: 0.1
# ============================================================
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode    1/2000 | Reward:   225.97 | Avg(10):   225.97 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode    2/2000 | Reward:   179.26 | Avg(10):   202.61 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode    3/2000 | Reward:   131.25 | Avg(10):   178.83 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode    4/2000 | Reward:    85.33 | Avg(10):   155.45 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode    5/2000 | Reward:    43.01 | Avg(10):   132.96 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode    6/2000 | Reward:   218.25 | Avg(10):   147.18 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode    7/2000 | Reward:   176.97 | Avg(10):   151.43 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode    8/2000 | Reward:   130.29 | Avg(10):   148.79 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode    9/2000 | Reward:    87.30 | Avg(10):   141.96 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   10/2000 | Reward:    44.25 | Avg(10):   132.19 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   11/2000 | Reward:   222.17 | Avg(10):   131.81 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   12/2000 | Reward:   167.90 | Avg(10):   130.67 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   13/2000 | Reward:   128.38 | Avg(10):   130.38 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   14/2000 | Reward:    85.61 | Avg(10):   130.41 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   15/2000 | Reward:    44.04 | Avg(10):   130.52 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   16/2000 | Reward:   222.08 | Avg(10):   130.90 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   17/2000 | Reward:   163.31 | Avg(10):   129.53 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   18/2000 | Reward:   130.36 | Avg(10):   129.54 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   19/2000 | Reward:    86.43 | Avg(10):   129.45 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   20/2000 | Reward:    45.21 | Avg(10):   129.55 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   21/2000 | Reward:   217.86 | Avg(10):   129.12 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   22/2000 | Reward:   153.24 | Avg(10):   127.65 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   23/2000 | Reward:   131.99 | Avg(10):   128.01 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   24/2000 | Reward:    85.82 | Avg(10):   128.03 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   25/2000 | Reward:    43.70 | Avg(10):   128.00 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   26/2000 | Reward:   219.45 | Avg(10):   127.74 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   27/2000 | Reward:   169.03 | Avg(10):   128.31 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   28/2000 | Reward:   130.29 | Avg(10):   128.30 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   29/2000 | Reward:    88.99 | Avg(10):   128.56 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   30/2000 | Reward:    43.73 | Avg(10):   128.41 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   31/2000 | Reward:   225.70 | Avg(10):   129.19 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   32/2000 | Reward:   167.61 | Avg(10):   130.63 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   33/2000 | Reward:   132.43 | Avg(10):   130.68 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   34/2000 | Reward:    87.41 | Avg(10):   130.83 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   35/2000 | Reward:    43.66 | Avg(10):   130.83 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   36/2000 | Reward:   218.87 | Avg(10):   130.77 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   37/2000 | Reward:   181.28 | Avg(10):   132.00 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   38/2000 | Reward:   130.41 | Avg(10):   132.01 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   39/2000 | Reward:    88.88 | Avg(10):   132.00 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   40/2000 | Reward:    43.52 | Avg(10):   131.98 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   41/2000 | Reward:   224.35 | Avg(10):   131.84 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   42/2000 | Reward:   175.23 | Avg(10):   132.61 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   43/2000 | Reward:   132.51 | Avg(10):   132.61 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   44/2000 | Reward:    85.62 | Avg(10):   132.43 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   45/2000 | Reward:    43.99 | Avg(10):   132.47 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   46/2000 | Reward:   219.31 | Avg(10):   132.51 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   47/2000 | Reward:   170.78 | Avg(10):   131.46 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   48/2000 | Reward:   128.83 | Avg(10):   131.30 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   49/2000 | Reward:    83.74 | Avg(10):   130.79 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   50/2000 | Reward:    45.23 | Avg(10):   130.96 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   51/2000 | Reward:   213.96 | Avg(10):   129.92 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   52/2000 | Reward:   177.62 | Avg(10):   130.16 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   53/2000 | Reward:   126.63 | Avg(10):   129.57 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   54/2000 | Reward:    84.53 | Avg(10):   129.46 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   55/2000 | Reward:    43.88 | Avg(10):   129.45 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   56/2000 | Reward:   210.12 | Avg(10):   128.53 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   57/2000 | Reward:   174.69 | Avg(10):   128.92 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   58/2000 | Reward:   130.06 | Avg(10):   129.05 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   59/2000 | Reward:    87.51 | Avg(10):   129.42 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   60/2000 | Reward:    43.72 | Avg(10):   129.27 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   61/2000 | Reward:   215.33 | Avg(10):   129.41 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   62/2000 | Reward:   174.76 | Avg(10):   129.12 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   63/2000 | Reward:   131.91 | Avg(10):   129.65 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   64/2000 | Reward:    87.18 | Avg(10):   129.92 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   65/2000 | Reward:    44.88 | Avg(10):   130.02 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   66/2000 | Reward:   221.09 | Avg(10):   131.11 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   67/2000 | Reward:   176.87 | Avg(10):   131.33 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   68/2000 | Reward:   132.64 | Avg(10):   131.59 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   69/2000 | Reward:    87.75 | Avg(10):   131.61 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   70/2000 | Reward:    44.27 | Avg(10):   131.67 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   71/2000 | Reward:   206.19 | Avg(10):   130.76 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   72/2000 | Reward:   168.91 | Avg(10):   130.17 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   73/2000 | Reward:   128.48 | Avg(10):   129.83 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   74/2000 | Reward:    86.19 | Avg(10):   129.73 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   75/2000 | Reward:    44.19 | Avg(10):   129.66 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   76/2000 | Reward:   213.10 | Avg(10):   128.86 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   77/2000 | Reward:   175.31 | Avg(10):   128.70 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   78/2000 | Reward:   134.40 | Avg(10):   128.88 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   79/2000 | Reward:    89.18 | Avg(10):   129.02 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   80/2000 | Reward:    44.39 | Avg(10):   129.03 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   81/2000 | Reward:   210.17 | Avg(10):   129.43 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   82/2000 | Reward:   170.87 | Avg(10):   129.63 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   83/2000 | Reward:   132.36 | Avg(10):   130.02 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   84/2000 | Reward:    87.60 | Avg(10):   130.16 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   85/2000 | Reward:    44.44 | Avg(10):   130.18 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   86/2000 | Reward:   215.66 | Avg(10):   130.44 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   87/2000 | Reward:   163.61 | Avg(10):   129.27 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   88/2000 | Reward:   132.09 | Avg(10):   129.04 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   89/2000 | Reward:    90.22 | Avg(10):   129.14 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   90/2000 | Reward:    43.38 | Avg(10):   129.04 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   91/2000 | Reward:   219.22 | Avg(10):   129.95 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   92/2000 | Reward:   177.01 | Avg(10):   130.56 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   93/2000 | Reward:   129.46 | Avg(10):   130.27 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   94/2000 | Reward:    89.25 | Avg(10):   130.43 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   95/2000 | Reward:    44.50 | Avg(10):   130.44 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   96/2000 | Reward:   225.33 | Avg(10):   131.41 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   97/2000 | Reward:   169.70 | Avg(10):   132.02 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   98/2000 | Reward:   132.70 | Avg(10):   132.08 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   99/2000 | Reward:    89.76 | Avg(10):   132.03 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  100/2000 | Reward:    44.14 | Avg(10):   132.11 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  101/2000 | Reward:   205.85 | Avg(10):   130.77 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  102/2000 | Reward:   161.10 | Avg(10):   129.18 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  103/2000 | Reward:   126.31 | Avg(10):   128.86 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  104/2000 | Reward:    89.11 | Avg(10):   128.85 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  105/2000 | Reward:    44.22 | Avg(10):   128.82 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  106/2000 | Reward:   197.67 | Avg(10):   126.06 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  107/2000 | Reward:   149.18 | Avg(10):   124.00 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  108/2000 | Reward:   114.26 | Avg(10):   122.16 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  109/2000 | Reward:    88.80 | Avg(10):   122.06 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  110/2000 | Reward:    41.36 | Avg(10):   121.79 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  111/2000 | Reward:   207.51 | Avg(10):   121.95 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  112/2000 | Reward:   167.56 | Avg(10):   122.60 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  113/2000 | Reward:   129.44 | Avg(10):   122.91 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  114/2000 | Reward:    88.67 | Avg(10):   122.87 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  115/2000 | Reward:    44.31 | Avg(10):   122.88 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  116/2000 | Reward:   226.42 | Avg(10):   125.75 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  117/2000 | Reward:   168.95 | Avg(10):   127.73 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  118/2000 | Reward:   131.82 | Avg(10):   129.48 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  119/2000 | Reward:    88.59 | Avg(10):   129.46 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  120/2000 | Reward:    44.18 | Avg(10):   129.75 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  121/2000 | Reward:   210.55 | Avg(10):   130.05 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  122/2000 | Reward:   167.11 | Avg(10):   130.00 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  123/2000 | Reward:   131.89 | Avg(10):   130.25 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  124/2000 | Reward:    85.50 | Avg(10):   129.93 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  125/2000 | Reward:    44.38 | Avg(10):   129.94 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  126/2000 | Reward:   194.65 | Avg(10):   126.76 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  127/2000 | Reward:   162.78 | Avg(10):   126.15 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  128/2000 | Reward:   132.83 | Avg(10):   126.25 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  129/2000 | Reward:    87.73 | Avg(10):   126.16 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  130/2000 | Reward:    44.09 | Avg(10):   126.15 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  131/2000 | Reward:   198.09 | Avg(10):   124.91 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  132/2000 | Reward:   151.44 | Avg(10):   123.34 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  133/2000 | Reward:   129.66 | Avg(10):   123.12 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  134/2000 | Reward:    90.19 | Avg(10):   123.59 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  135/2000 | Reward:    44.08 | Avg(10):   123.55 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  136/2000 | Reward:   227.98 | Avg(10):   126.89 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  137/2000 | Reward:   160.95 | Avg(10):   126.70 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  138/2000 | Reward:   133.58 | Avg(10):   126.78 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  139/2000 | Reward:    89.24 | Avg(10):   126.93 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  140/2000 | Reward:    44.50 | Avg(10):   126.97 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  141/2000 | Reward:   225.89 | Avg(10):   129.75 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  142/2000 | Reward:   171.64 | Avg(10):   131.77 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  143/2000 | Reward:   131.61 | Avg(10):   131.97 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  144/2000 | Reward:    87.98 | Avg(10):   131.74 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  145/2000 | Reward:    44.48 | Avg(10):   131.78 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  146/2000 | Reward:   201.20 | Avg(10):   129.11 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  147/2000 | Reward:   168.03 | Avg(10):   129.81 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  148/2000 | Reward:   132.92 | Avg(10):   129.75 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  149/2000 | Reward:    87.89 | Avg(10):   129.61 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  150/2000 | Reward:    44.31 | Avg(10):   129.59 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  151/2000 | Reward:   205.10 | Avg(10):   127.52 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  152/2000 | Reward:   171.44 | Avg(10):   127.50 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  153/2000 | Reward:   134.95 | Avg(10):   127.83 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  154/2000 | Reward:    88.89 | Avg(10):   127.92 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  155/2000 | Reward:    43.86 | Avg(10):   127.86 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  156/2000 | Reward:   218.05 | Avg(10):   129.54 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  157/2000 | Reward:   148.14 | Avg(10):   127.56 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  158/2000 | Reward:   133.04 | Avg(10):   127.57 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  159/2000 | Reward:    88.33 | Avg(10):   127.61 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  160/2000 | Reward:    43.71 | Avg(10):   127.55 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  161/2000 | Reward:   209.80 | Avg(10):   128.02 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  162/2000 | Reward:   154.06 | Avg(10):   126.28 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  163/2000 | Reward:   131.52 | Avg(10):   125.94 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  164/2000 | Reward:    89.02 | Avg(10):   125.95 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  165/2000 | Reward:    44.30 | Avg(10):   126.00 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  166/2000 | Reward:   201.82 | Avg(10):   124.37 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  167/2000 | Reward:   144.21 | Avg(10):   123.98 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  168/2000 | Reward:   132.79 | Avg(10):   123.96 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  169/2000 | Reward:    86.92 | Avg(10):   123.82 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  170/2000 | Reward:    43.37 | Avg(10):   123.78 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  171/2000 | Reward:   223.80 | Avg(10):   125.18 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  172/2000 | Reward:   161.94 | Avg(10):   125.97 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  173/2000 | Reward:   127.53 | Avg(10):   125.57 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  174/2000 | Reward:    85.61 | Avg(10):   125.23 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  175/2000 | Reward:    43.07 | Avg(10):   125.11 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  176/2000 | Reward:   199.18 | Avg(10):   124.84 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  177/2000 | Reward:   158.88 | Avg(10):   126.31 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  178/2000 | Reward:   132.81 | Avg(10):   126.31 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  179/2000 | Reward:    88.23 | Avg(10):   126.44 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  180/2000 | Reward:    44.40 | Avg(10):   126.54 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  181/2000 | Reward:   207.57 | Avg(10):   124.92 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  182/2000 | Reward:   176.82 | Avg(10):   126.41 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  183/2000 | Reward:   129.37 | Avg(10):   126.59 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  184/2000 | Reward:    80.54 | Avg(10):   126.08 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  185/2000 | Reward:    43.97 | Avg(10):   126.18 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  186/2000 | Reward:   217.00 | Avg(10):   127.96 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  187/2000 | Reward:   165.60 | Avg(10):   128.63 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  188/2000 | Reward:   129.79 | Avg(10):   128.33 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  189/2000 | Reward:    85.28 | Avg(10):   128.03 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  190/2000 | Reward:    44.28 | Avg(10):   128.02 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  191/2000 | Reward:   210.30 | Avg(10):   128.30 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  192/2000 | Reward:   172.89 | Avg(10):   127.90 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  193/2000 | Reward:   134.16 | Avg(10):   128.38 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  194/2000 | Reward:    86.70 | Avg(10):   129.00 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  195/2000 | Reward:    44.53 | Avg(10):   129.05 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  196/2000 | Reward:   211.87 | Avg(10):   128.54 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  197/2000 | Reward:   172.55 | Avg(10):   129.24 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  198/2000 | Reward:   129.58 | Avg(10):   129.21 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  199/2000 | Reward:    87.49 | Avg(10):   129.44 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  200/2000 | Reward:    44.48 | Avg(10):   129.45 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  201/2000 | Reward:   193.55 | Avg(10):   127.78 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  202/2000 | Reward:   152.20 | Avg(10):   125.71 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  203/2000 | Reward:   129.23 | Avg(10):   125.22 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  204/2000 | Reward:    84.91 | Avg(10):   125.04 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  205/2000 | Reward:    44.23 | Avg(10):   125.01 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  206/2000 | Reward:   218.23 | Avg(10):   125.64 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  207/2000 | Reward:   174.41 | Avg(10):   125.83 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  208/2000 | Reward:   132.41 | Avg(10):   126.11 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  209/2000 | Reward:    88.32 | Avg(10):   126.20 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  210/2000 | Reward:    44.38 | Avg(10):   126.19 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  211/2000 | Reward:   226.25 | Avg(10):   129.46 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  212/2000 | Reward:   161.64 | Avg(10):   130.40 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  213/2000 | Reward:   126.85 | Avg(10):   130.16 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  214/2000 | Reward:    89.00 | Avg(10):   130.57 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  215/2000 | Reward:    44.50 | Avg(10):   130.60 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  216/2000 | Reward:   207.71 | Avg(10):   129.55 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  217/2000 | Reward:   165.62 | Avg(10):   128.67 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  218/2000 | Reward:   133.65 | Avg(10):   128.79 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  219/2000 | Reward:    86.22 | Avg(10):   128.58 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  220/2000 | Reward:    45.00 | Avg(10):   128.64 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  221/2000 | Reward:   202.49 | Avg(10):   126.27 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  222/2000 | Reward:   178.35 | Avg(10):   127.94 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  223/2000 | Reward:   130.07 | Avg(10):   128.26 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  224/2000 | Reward:    82.58 | Avg(10):   127.62 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  225/2000 | Reward:    42.60 | Avg(10):   127.43 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  226/2000 | Reward:   199.61 | Avg(10):   126.62 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  227/2000 | Reward:   155.53 | Avg(10):   125.61 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  228/2000 | Reward:   132.65 | Avg(10):   125.51 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  229/2000 | Reward:    83.86 | Avg(10):   125.27 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  230/2000 | Reward:    43.98 | Avg(10):   125.17 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  231/2000 | Reward:   203.48 | Avg(10):   125.27 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  232/2000 | Reward:   170.64 | Avg(10):   124.50 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  233/2000 | Reward:   126.58 | Avg(10):   124.15 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  234/2000 | Reward:    88.36 | Avg(10):   124.73 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  235/2000 | Reward:    44.35 | Avg(10):   124.90 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  236/2000 | Reward:   212.18 | Avg(10):   126.16 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  237/2000 | Reward:   176.53 | Avg(10):   128.26 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  238/2000 | Reward:   130.05 | Avg(10):   128.00 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  239/2000 | Reward:    88.91 | Avg(10):   128.51 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  240/2000 | Reward:    43.85 | Avg(10):   128.49 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  241/2000 | Reward:   221.88 | Avg(10):   130.33 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  242/2000 | Reward:   167.52 | Avg(10):   130.02 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  243/2000 | Reward:   130.96 | Avg(10):   130.46 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  244/2000 | Reward:    86.95 | Avg(10):   130.32 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  245/2000 | Reward:    43.29 | Avg(10):   130.21 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  246/2000 | Reward:   207.42 | Avg(10):   129.73 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  247/2000 | Reward:   172.59 | Avg(10):   129.34 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  248/2000 | Reward:   127.66 | Avg(10):   129.10 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  249/2000 | Reward:    87.15 | Avg(10):   128.93 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  250/2000 | Reward:    44.22 | Avg(10):   128.96 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  251/2000 | Reward:   200.64 | Avg(10):   126.84 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  252/2000 | Reward:   150.79 | Avg(10):   125.17 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  253/2000 | Reward:   127.23 | Avg(10):   124.79 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  254/2000 | Reward:    86.96 | Avg(10):   124.80 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  255/2000 | Reward:    43.46 | Avg(10):   124.81 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  256/2000 | Reward:   205.69 | Avg(10):   124.64 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  257/2000 | Reward:   155.84 | Avg(10):   122.96 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  258/2000 | Reward:   130.63 | Avg(10):   123.26 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  259/2000 | Reward:    86.96 | Avg(10):   123.24 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  260/2000 | Reward:    43.11 | Avg(10):   123.13 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  261/2000 | Reward:   207.15 | Avg(10):   123.78 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  262/2000 | Reward:   158.64 | Avg(10):   124.57 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  263/2000 | Reward:   131.61 | Avg(10):   125.00 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  264/2000 | Reward:    88.04 | Avg(10):   125.11 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  265/2000 | Reward:    44.10 | Avg(10):   125.18 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  266/2000 | Reward:   226.63 | Avg(10):   127.27 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  267/2000 | Reward:   160.77 | Avg(10):   127.76 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  268/2000 | Reward:   127.40 | Avg(10):   127.44 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  269/2000 | Reward:    88.04 | Avg(10):   127.55 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  270/2000 | Reward:    44.38 | Avg(10):   127.67 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  271/2000 | Reward:   219.37 | Avg(10):   128.90 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  272/2000 | Reward:   166.99 | Avg(10):   129.73 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  273/2000 | Reward:   130.66 | Avg(10):   129.64 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  274/2000 | Reward:    88.26 | Avg(10):   129.66 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  275/2000 | Reward:    44.03 | Avg(10):   129.65 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  276/2000 | Reward:   209.48 | Avg(10):   127.94 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  277/2000 | Reward:   173.25 | Avg(10):   129.19 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  278/2000 | Reward:   126.56 | Avg(10):   129.10 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  279/2000 | Reward:    86.45 | Avg(10):   128.94 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  280/2000 | Reward:    43.12 | Avg(10):   128.82 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  281/2000 | Reward:   218.26 | Avg(10):   128.71 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  282/2000 | Reward:   171.14 | Avg(10):   129.12 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  283/2000 | Reward:   124.49 | Avg(10):   128.50 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  284/2000 | Reward:    87.71 | Avg(10):   128.45 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  285/2000 | Reward:    43.78 | Avg(10):   128.42 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  286/2000 | Reward:   214.45 | Avg(10):   128.92 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  287/2000 | Reward:   171.21 | Avg(10):   128.72 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  288/2000 | Reward:   131.95 | Avg(10):   129.26 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  289/2000 | Reward:    86.93 | Avg(10):   129.30 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  290/2000 | Reward:    45.00 | Avg(10):   129.49 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  291/2000 | Reward:   219.48 | Avg(10):   129.61 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  292/2000 | Reward:   170.37 | Avg(10):   129.54 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  293/2000 | Reward:   127.12 | Avg(10):   129.80 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  294/2000 | Reward:    87.02 | Avg(10):   129.73 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  295/2000 | Reward:    44.13 | Avg(10):   129.77 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  296/2000 | Reward:   218.70 | Avg(10):   130.19 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  297/2000 | Reward:   172.13 | Avg(10):   130.28 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  298/2000 | Reward:   128.68 | Avg(10):   129.96 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  299/2000 | Reward:    89.00 | Avg(10):   130.16 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  300/2000 | Reward:    43.33 | Avg(10):   130.00 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  301/2000 | Reward:   220.96 | Avg(10):   130.14 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  302/2000 | Reward:   174.84 | Avg(10):   130.59 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  303/2000 | Reward:   131.21 | Avg(10):   131.00 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  304/2000 | Reward:    88.39 | Avg(10):   131.14 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  305/2000 | Reward:    42.95 | Avg(10):   131.02 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  306/2000 | Reward:   221.52 | Avg(10):   131.30 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  307/2000 | Reward:   158.90 | Avg(10):   129.98 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  308/2000 | Reward:   129.63 | Avg(10):   130.07 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  309/2000 | Reward:    88.95 | Avg(10):   130.07 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  310/2000 | Reward:    43.72 | Avg(10):   130.11 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  311/2000 | Reward:   206.41 | Avg(10):   128.65 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  312/2000 | Reward:   162.72 | Avg(10):   127.44 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  313/2000 | Reward:   133.53 | Avg(10):   127.67 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  314/2000 | Reward:    88.14 | Avg(10):   127.65 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  315/2000 | Reward:    43.66 | Avg(10):   127.72 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  316/2000 | Reward:   207.00 | Avg(10):   126.27 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  317/2000 | Reward:   166.82 | Avg(10):   127.06 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  318/2000 | Reward:   126.26 | Avg(10):   126.72 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  319/2000 | Reward:    88.33 | Avg(10):   126.66 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  320/2000 | Reward:    44.08 | Avg(10):   126.69 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  321/2000 | Reward:   212.43 | Avg(10):   127.30 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  322/2000 | Reward:   162.00 | Avg(10):   127.22 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  323/2000 | Reward:   130.80 | Avg(10):   126.95 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  324/2000 | Reward:    85.63 | Avg(10):   126.70 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  325/2000 | Reward:    44.53 | Avg(10):   126.79 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  326/2000 | Reward:   221.11 | Avg(10):   128.20 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# ...
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1892/2000 | Reward:   164.36 | Avg(10):   128.33 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1893/2000 | Reward:   133.66 | Avg(10):   129.07 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1894/2000 | Reward:    88.03 | Avg(10):   129.11 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1895/2000 | Reward:    43.84 | Avg(10):   129.04 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1896/2000 | Reward:   224.77 | Avg(10):   129.96 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1897/2000 | Reward:   172.89 | Avg(10):   130.36 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1898/2000 | Reward:   132.26 | Avg(10):   130.43 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1899/2000 | Reward:    79.04 | Avg(10):   129.46 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1900/2000 | Reward:    44.99 | Avg(10):   129.53 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1901/2000 | Reward:   208.62 | Avg(10):   129.24 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1902/2000 | Reward:   164.57 | Avg(10):   129.27 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1903/2000 | Reward:   129.68 | Avg(10):   128.87 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1904/2000 | Reward:    88.69 | Avg(10):   128.93 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1905/2000 | Reward:    44.82 | Avg(10):   129.03 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1906/2000 | Reward:   228.53 | Avg(10):   129.41 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1907/2000 | Reward:   180.25 | Avg(10):   130.15 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1908/2000 | Reward:   132.86 | Avg(10):   130.20 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1909/2000 | Reward:    87.12 | Avg(10):   131.01 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1910/2000 | Reward:    44.61 | Avg(10):   130.98 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1911/2000 | Reward:   212.73 | Avg(10):   131.39 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1912/2000 | Reward:   160.23 | Avg(10):   130.95 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1913/2000 | Reward:   132.91 | Avg(10):   131.28 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1914/2000 | Reward:    89.53 | Avg(10):   131.36 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1915/2000 | Reward:    44.14 | Avg(10):   131.29 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1916/2000 | Reward:   228.40 | Avg(10):   131.28 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1917/2000 | Reward:   179.11 | Avg(10):   131.17 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1918/2000 | Reward:   132.06 | Avg(10):   131.09 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1919/2000 | Reward:    88.32 | Avg(10):   131.21 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1920/2000 | Reward:    44.15 | Avg(10):   131.16 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1921/2000 | Reward:   224.86 | Avg(10):   132.37 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1922/2000 | Reward:   179.92 | Avg(10):   134.34 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1923/2000 | Reward:   132.87 | Avg(10):   134.34 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1924/2000 | Reward:    88.89 | Avg(10):   134.27 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1925/2000 | Reward:    36.89 | Avg(10):   133.55 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1926/2000 | Reward:   229.47 | Avg(10):   133.66 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1927/2000 | Reward:   179.66 | Avg(10):   133.71 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1928/2000 | Reward:   134.27 | Avg(10):   133.93 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1929/2000 | Reward:    87.27 | Avg(10):   133.82 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1930/2000 | Reward:    44.05 | Avg(10):   133.81 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1931/2000 | Reward:   213.63 | Avg(10):   132.69 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1932/2000 | Reward:   179.01 | Avg(10):   132.60 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1933/2000 | Reward:   132.11 | Avg(10):   132.52 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1934/2000 | Reward:    88.95 | Avg(10):   132.53 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1935/2000 | Reward:    44.50 | Avg(10):   133.29 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1936/2000 | Reward:   223.64 | Avg(10):   132.71 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1937/2000 | Reward:   168.87 | Avg(10):   131.63 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1938/2000 | Reward:   130.09 | Avg(10):   131.21 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1939/2000 | Reward:    88.70 | Avg(10):   131.35 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1940/2000 | Reward:    44.60 | Avg(10):   131.41 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1941/2000 | Reward:   209.86 | Avg(10):   131.03 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1942/2000 | Reward:   176.30 | Avg(10):   130.76 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1943/2000 | Reward:   130.92 | Avg(10):   130.64 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1944/2000 | Reward:    88.23 | Avg(10):   130.57 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1945/2000 | Reward:    44.06 | Avg(10):   130.53 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1946/2000 | Reward:   217.54 | Avg(10):   129.92 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1947/2000 | Reward:   170.16 | Avg(10):   130.05 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1948/2000 | Reward:   131.01 | Avg(10):   130.14 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1949/2000 | Reward:    88.08 | Avg(10):   130.08 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1950/2000 | Reward:    43.93 | Avg(10):   130.01 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1951/2000 | Reward:   215.99 | Avg(10):   130.62 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1952/2000 | Reward:   179.61 | Avg(10):   130.95 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1953/2000 | Reward:   126.04 | Avg(10):   130.46 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1954/2000 | Reward:    88.06 | Avg(10):   130.45 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1955/2000 | Reward:    43.18 | Avg(10):   130.36 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1956/2000 | Reward:   211.48 | Avg(10):   129.75 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1957/2000 | Reward:   179.34 | Avg(10):   130.67 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1958/2000 | Reward:   133.38 | Avg(10):   130.91 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1959/2000 | Reward:    88.60 | Avg(10):   130.96 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1960/2000 | Reward:    35.47 | Avg(10):   130.11 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1961/2000 | Reward:   207.22 | Avg(10):   129.24 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1962/2000 | Reward:   179.84 | Avg(10):   129.26 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1963/2000 | Reward:   133.46 | Avg(10):   130.00 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1964/2000 | Reward:    88.35 | Avg(10):   130.03 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1965/2000 | Reward:    43.98 | Avg(10):   130.11 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1966/2000 | Reward:   219.43 | Avg(10):   130.91 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1967/2000 | Reward:   179.99 | Avg(10):   130.97 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1968/2000 | Reward:   132.05 | Avg(10):   130.84 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1969/2000 | Reward:    88.77 | Avg(10):   130.86 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1970/2000 | Reward:    43.61 | Avg(10):   131.67 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1971/2000 | Reward:   221.95 | Avg(10):   133.14 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1972/2000 | Reward:   164.61 | Avg(10):   131.62 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1973/2000 | Reward:   131.17 | Avg(10):   131.39 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1974/2000 | Reward:    88.94 | Avg(10):   131.45 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1975/2000 | Reward:    44.34 | Avg(10):   131.49 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1976/2000 | Reward:   212.00 | Avg(10):   130.74 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1977/2000 | Reward:   170.00 | Avg(10):   129.74 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1978/2000 | Reward:   132.86 | Avg(10):   129.83 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1979/2000 | Reward:    88.09 | Avg(10):   129.76 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1980/2000 | Reward:    44.50 | Avg(10):   129.85 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1981/2000 | Reward:   209.15 | Avg(10):   128.57 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1982/2000 | Reward:   164.32 | Avg(10):   128.54 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1983/2000 | Reward:   127.87 | Avg(10):   128.21 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1984/2000 | Reward:    88.78 | Avg(10):   128.19 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1985/2000 | Reward:    44.51 | Avg(10):   128.21 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1986/2000 | Reward:   228.49 | Avg(10):   129.86 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1987/2000 | Reward:   167.98 | Avg(10):   129.66 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1988/2000 | Reward:   133.83 | Avg(10):   129.75 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1989/2000 | Reward:    89.21 | Avg(10):   129.87 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1990/2000 | Reward:    43.66 | Avg(10):   129.78 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1991/2000 | Reward:   219.17 | Avg(10):   130.78 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1992/2000 | Reward:   168.09 | Avg(10):   131.16 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1993/2000 | Reward:   132.86 | Avg(10):   131.66 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1994/2000 | Reward:    88.89 | Avg(10):   131.67 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1995/2000 | Reward:    44.15 | Avg(10):   131.64 | Steps:   72
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1996/2000 | Reward:   219.94 | Avg(10):   130.78 | Steps:  363
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1997/2000 | Reward:   166.75 | Avg(10):   130.66 | Steps:  291
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1998/2000 | Reward:   133.47 | Avg(10):   130.62 | Steps:  218
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 1999/2000 | Reward:    89.19 | Avg(10):   130.62 | Steps:  145
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode 2000/2000 | Reward:    42.93 | Avg(10):   130.54 | Steps:   72
#
# [QLearningAgent] Training complete!

# %% [markdown]
# ## 5. Save Agent

# %%
save_path = os.path.join(SAVE_DIR, 'qlearning.pkl')
agent.save(save_path)
print(f'Saved → {save_path}')
print(f'States visited : {len(agent.Q)}')
# Out:
# [QLearningAgent] Saved → /kaggle/working/RL-concept-drift/experiments/saved_models/qlearning.pkl
# Saved → /kaggle/working/RL-concept-drift/experiments/saved_models/qlearning.pkl
# States visited : 244

# %% [markdown]
# ## 6. Learning Curve

# %%
rewards = history['episode_rewards']
print(f'Avg reward (all)    : {np.mean(rewards):.4f}')
print(f'Avg reward (last 10): {np.mean(rewards[-10:]):.4f}')
print(f'Best episode reward : {max(rewards):.4f}')
print(f'Action distribution : {history["action_counts"]}')

plot_cumulative_reward(
    {'Q-Learning': rewards},
    title    = 'Q-Learning – Episode Reward over Training (Train Stream)',
    filename = 'qlearning_learning_curve.png',
)
# Out:
# Avg reward (all)    : 129.8942
# Avg reward (last 10): 130.5439
# Best episode reward : 231.6120
# Action distribution : {'no_action': 150786, 'partial_update': 17688, 'full_retrain': 9612, 'alert': 137389, 'switch_model': 120125}
# [Visualizer] Saved → /kaggle/working/RL-concept-drift/experiments/results/qlearning_learning_curve.png

# %% [markdown]
# ## 7. Quick Sanity Check – Greedy Policy

# %%
# Set epsilon = 0.0 → pure greedy để kiểm tra policy đã học
agent.epsilon = 0.0
print(f'Top 10 states by Q-value spread:')
items = sorted(
    agent.Q.items(),
    key=lambda x: np.max(x[1]) - np.min(x[1]),
    reverse=True
)[:10]
for state, q in items:
    best_action = int(np.argmax(q))
    from environment.drift_env import ACTIONS
    print(f'  {state} → {ACTIONS[best_action]:<16} Q={np.round(q,3)}')

# Restore epsilon
agent.epsilon = 0.1
# Out:
# Top 10 states by Q-value spread:
#   (1, 0, 3, 0, 0) → no_action        Q=[6.386 1.121 2.074 1.444 0.   ]
#   (0, 0, 3, 0, 0) → no_action        Q=[6.384 0.    0.607 0.645 0.634]
#   (1, 2, 1, 1, 0) → no_action        Q=[6.1   1.558 2.277 0.    0.   ]
#   (1, 0, 2, 2, 0) → no_action        Q=[6.063 0.    0.378 2.056 2.098]
#   (1, 2, 2, 1, 0) → no_action        Q=[5.908 0.578 0.578 0.611 0.   ]
#   (2, 0, 1, 2, 1) → no_action        Q=[5.887 0.585 0.    0.607 0.   ]
#   (0, 0, 0, 0, 0) → no_action        Q=[6.487 0.608 1.113 0.637 1.73 ]
#   (2, 1, 2, 1, 0) → no_action        Q=[5.858 0.    1.075 0.49  0.204]
#   (1, 2, 2, 2, 0) → no_action        Q=[5.85  0.    0.576 2.058 0.   ]
#   (4, 2, 0, 1, 0) → no_action        Q=[5.848 1.1   0.569 0.    1.576]
