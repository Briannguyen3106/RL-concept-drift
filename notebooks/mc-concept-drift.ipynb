# %% [markdown]
# # 02 – MC Agent Experiment
#
# **Flow:**
# 1. Setup & load data
# 2. Phase 1 – Train MC Agent trên train stream (batch 0-363, 70%)
# 3. Warm-up – Retrain tất cả models trên `FULL_WINDOW_BATCHES` batches cuối train stream
# 4. Phase 2 – Evaluate công bằng trên test stream (batch 364-519, 30%)
#    - MC Agent: dùng learned policy, **không update thêm**
#    - Static   : không retrain
#    - Periodic : retrain mỗi 50 batches
#    - Always   : retrain mỗi batch
# 5. Visualize & so sánh

# %%
#!git clone https://github.com/Briannguyen3106/RL-concept-drift.git
#%cd RL-concept-drift
#!pip install -r requirements.txt
# Out:
# Cloning into 'RL-concept-drift'...
# remote: Enumerating objects: 110, done.
# remote: Counting objects: 100% (110/110), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 110 (delta 34), reused 98 (delta 22), pack-reused 0 (from 0)
# Receiving objects: 100% (110/110), 11.43 MiB | 26.30 MiB/s, done.
# Resolving deltas: 100% (34/34), done.
# /kaggle/working/RL-concept-drift
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (2.3.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (1.6.1)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (4.6.0)
# Collecting mplcursors (from -r requirements.txt (line 7))
#   Downloading mplcursors-0.7.1-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 2)) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 3)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 3)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 3)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 3)) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 3)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 5)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 2)) (1.17.0)
# Downloading mplcursors-0.7.1-py3-none-any.whl (20 kB)
# Installing collected packages: mplcursors
# Successfully installed mplcursors-0.7.1

# %% [markdown]
# ## 1. Setup

# %%
import sys, os
import numpy as np
import pandas as pd
import copy
from collections import deque

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

from config import (
    BATCH_SIZE, CATEGORICAL_COLS,
    FULL_WINDOW_BATCHES, PARTIAL_WINDOW_BATCHES,
)
from utils.data_loader import AirlinesDataLoader
from models.LightGBM import LightGBM
from metrics.stream_metrics import StreamMetrics
from environment.drift_env import DriftStreamEnv
from agents.mc_agent import MCAgent
from utils.visualizer import (
    plot_dashboard,
    plot_cumulative_reward,
    plot_action_distribution,
    plot_agent_vs_baselines,
    plot_retrain_events,
)

print('Setup complete!')
# Out:
# Setup complete!

# %% [markdown]
# ## 2. Load Data

# %%
loader = AirlinesDataLoader()
X_train, y_train = loader.get_initial_train_data()

print(f'Initial train size : {len(X_train):,}')
print(f'Total stream       : {loader.n_batches} batches')
print(f'Train stream       : {loader.n_train_batches} batches  (batch 0 – {loader.n_train_batches-1})')
print(f'Test  stream       : {loader.n_test_batches} batches  (batch {loader.n_train_batches} – {loader.n_batches-1})')
print(f'Warm-up window     : {FULL_WINDOW_BATCHES} batches  (cuối train stream)')
# Out:
# [DataLoader] Loading data from: /kaggle/working/RL-concept-drift/data/Airlines.csv
# [DataLoader] Raw shape: (539383, 9)
# [DataLoader] 'Airline' → category dtype (18 unique values)
# [DataLoader] 'AirportFrom' → category dtype (293 unique values)
# [DataLoader] 'AirportTo' → category dtype (293 unique values)
# [DataLoader] Initial train size : 20,000
# [DataLoader] Stream size        : 519,383
# [DataLoader] Class distribution (train) – 0: 11,529 | 1: 8,471
# [DataLoader] Stream split → Train: 363 batches | Test: 156 batches
# Initial train size : 20,000
# Total stream       : 519 batches
# Train stream       : 363 batches  (batch 0 – 362)
# Test  stream       : 156 batches  (batch 363 – 518)
# Warm-up window     : 10 batches  (cuối train stream)

# %% [markdown]
# ## 3. Phase 1 – Train MC Agent
#
# Agent được train **chỉ trên train stream** (70% đầu).
# `env.reset(mode="train")` → `stream_train_batches()` → batch 0 đến {n_train-1}.
#
# Baselines **không chạy ở phase này** – chúng sẽ được so sánh ở phase 2.

# %%
clf     = LightGBM()
metrics = StreamMetrics()
env     = DriftStreamEnv(loader, clf, metrics)
agent   = MCAgent()

N_TRAIN_EPISODES = 200    # Tăng/giảm tuỳ thời gian chạy

# train() trong BaseAgent tự rotate start_batch theo MC_EPISODE_STARTS
# reset() mặc định mode="train" → stream_train_batches()
training_history = agent.train(env, n_episodes=N_TRAIN_EPISODES, verbose=True)

print(f'\nStates visited      : {len(agent.Q)}')
print(f'Preferences learned : {len(agent.H)}')
print(f'Final temperature   : {agent.temp:.4f}')
# Out:
# ============================================================
# Training MCAgent for 200 episodes
# ============================================================
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode    1/200 | Reward:   200.65 | Avg(10):   200.65 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode    2/200 | Reward:   158.10 | Avg(10):   179.38 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode    3/200 | Reward:   119.92 | Avg(10):   159.56 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode    4/200 | Reward:    82.26 | Avg(10):   140.23 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode    5/200 | Reward:    37.33 | Avg(10):   119.65 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode    6/200 | Reward:   198.53 | Avg(10):   132.80 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode    7/200 | Reward:   155.55 | Avg(10):   136.05 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode    8/200 | Reward:   121.19 | Avg(10):   134.19 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode    9/200 | Reward:    80.68 | Avg(10):   128.25 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   10/200 | Reward:    40.39 | Avg(10):   119.46 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   11/200 | Reward:   198.36 | Avg(10):   119.23 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   12/200 | Reward:   159.42 | Avg(10):   119.36 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   13/200 | Reward:   124.55 | Avg(10):   119.83 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   14/200 | Reward:    83.80 | Avg(10):   119.98 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   15/200 | Reward:    40.19 | Avg(10):   120.27 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   16/200 | Reward:   213.37 | Avg(10):   121.75 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   17/200 | Reward:   161.32 | Avg(10):   122.33 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   18/200 | Reward:   124.60 | Avg(10):   122.67 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   19/200 | Reward:    79.08 | Avg(10):   122.51 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   20/200 | Reward:    41.05 | Avg(10):   122.57 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   21/200 | Reward:   199.81 | Avg(10):   122.72 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   22/200 | Reward:   165.07 | Avg(10):   123.28 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   23/200 | Reward:   123.81 | Avg(10):   123.21 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   24/200 | Reward:    83.32 | Avg(10):   123.16 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   25/200 | Reward:    38.53 | Avg(10):   123.00 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   26/200 | Reward:   209.95 | Avg(10):   122.66 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   27/200 | Reward:   167.63 | Avg(10):   123.29 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   28/200 | Reward:   126.84 | Avg(10):   123.51 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   29/200 | Reward:    84.70 | Avg(10):   124.07 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   30/200 | Reward:    38.38 | Avg(10):   123.80 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   31/200 | Reward:   212.48 | Avg(10):   125.07 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   32/200 | Reward:   168.46 | Avg(10):   125.41 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   33/200 | Reward:   127.78 | Avg(10):   125.81 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   34/200 | Reward:    85.88 | Avg(10):   126.06 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   35/200 | Reward:    41.72 | Avg(10):   126.38 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   36/200 | Reward:   208.49 | Avg(10):   126.24 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   37/200 | Reward:   166.60 | Avg(10):   126.13 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   38/200 | Reward:   125.06 | Avg(10):   125.95 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   39/200 | Reward:    86.45 | Avg(10):   126.13 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   40/200 | Reward:    43.74 | Avg(10):   126.67 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   41/200 | Reward:   218.44 | Avg(10):   127.26 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   42/200 | Reward:   168.69 | Avg(10):   127.29 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   43/200 | Reward:   126.20 | Avg(10):   127.13 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   44/200 | Reward:    86.69 | Avg(10):   127.21 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   45/200 | Reward:    37.39 | Avg(10):   126.78 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   46/200 | Reward:   222.03 | Avg(10):   128.13 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   47/200 | Reward:   169.76 | Avg(10):   128.45 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   48/200 | Reward:   129.69 | Avg(10):   128.91 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   49/200 | Reward:    83.67 | Avg(10):   128.63 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   50/200 | Reward:    42.46 | Avg(10):   128.50 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   51/200 | Reward:   215.97 | Avg(10):   128.25 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   52/200 | Reward:   178.81 | Avg(10):   129.27 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   53/200 | Reward:   128.16 | Avg(10):   129.46 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   54/200 | Reward:    86.00 | Avg(10):   129.39 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   55/200 | Reward:    44.43 | Avg(10):   130.10 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   56/200 | Reward:   216.15 | Avg(10):   129.51 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   57/200 | Reward:   170.98 | Avg(10):   129.63 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   58/200 | Reward:   127.08 | Avg(10):   129.37 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   59/200 | Reward:    87.28 | Avg(10):   129.73 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   60/200 | Reward:    41.40 | Avg(10):   129.63 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   61/200 | Reward:   213.90 | Avg(10):   129.42 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   62/200 | Reward:   168.38 | Avg(10):   128.38 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   63/200 | Reward:   132.03 | Avg(10):   128.76 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   64/200 | Reward:    86.91 | Avg(10):   128.85 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   65/200 | Reward:    44.20 | Avg(10):   128.83 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   66/200 | Reward:   215.70 | Avg(10):   128.78 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   67/200 | Reward:   171.79 | Avg(10):   128.87 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   68/200 | Reward:   132.02 | Avg(10):   129.36 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   69/200 | Reward:    85.50 | Avg(10):   129.18 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   70/200 | Reward:    43.78 | Avg(10):   129.42 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   71/200 | Reward:   216.36 | Avg(10):   129.67 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   72/200 | Reward:   178.54 | Avg(10):   130.68 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   73/200 | Reward:   128.99 | Avg(10):   130.38 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   74/200 | Reward:    86.94 | Avg(10):   130.38 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   75/200 | Reward:    38.77 | Avg(10):   129.84 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   76/200 | Reward:   222.22 | Avg(10):   130.49 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   77/200 | Reward:   176.47 | Avg(10):   130.96 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   78/200 | Reward:   131.38 | Avg(10):   130.90 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   79/200 | Reward:    86.71 | Avg(10):   131.02 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   80/200 | Reward:    43.76 | Avg(10):   131.02 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   81/200 | Reward:   220.59 | Avg(10):   131.44 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   82/200 | Reward:   175.63 | Avg(10):   131.15 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   83/200 | Reward:   130.56 | Avg(10):   131.30 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   84/200 | Reward:    86.44 | Avg(10):   131.25 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   85/200 | Reward:    44.08 | Avg(10):   131.78 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   86/200 | Reward:   210.25 | Avg(10):   130.59 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   87/200 | Reward:   164.33 | Avg(10):   129.37 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   88/200 | Reward:   129.87 | Avg(10):   129.22 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   89/200 | Reward:    87.15 | Avg(10):   129.27 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   90/200 | Reward:    44.50 | Avg(10):   129.34 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   91/200 | Reward:   221.79 | Avg(10):   129.46 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   92/200 | Reward:   178.25 | Avg(10):   129.72 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   93/200 | Reward:   132.89 | Avg(10):   129.95 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   94/200 | Reward:    85.48 | Avg(10):   129.86 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   95/200 | Reward:    43.41 | Avg(10):   129.79 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   96/200 | Reward:   224.75 | Avg(10):   131.24 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   97/200 | Reward:   174.18 | Avg(10):   132.23 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   98/200 | Reward:   130.98 | Avg(10):   132.34 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode   99/200 | Reward:    88.48 | Avg(10):   132.47 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  100/200 | Reward:    39.57 | Avg(10):   131.98 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  101/200 | Reward:   220.56 | Avg(10):   131.86 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  102/200 | Reward:   177.92 | Avg(10):   131.82 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  103/200 | Reward:   132.46 | Avg(10):   131.78 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  104/200 | Reward:    87.43 | Avg(10):   131.97 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  105/200 | Reward:    43.73 | Avg(10):   132.01 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  106/200 | Reward:   224.96 | Avg(10):   132.03 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  107/200 | Reward:   179.40 | Avg(10):   132.55 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  108/200 | Reward:   130.51 | Avg(10):   132.50 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  109/200 | Reward:    88.72 | Avg(10):   132.53 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  110/200 | Reward:    42.76 | Avg(10):   132.85 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  111/200 | Reward:   218.12 | Avg(10):   132.60 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  112/200 | Reward:   172.24 | Avg(10):   132.03 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  113/200 | Reward:   132.11 | Avg(10):   132.00 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  114/200 | Reward:    88.42 | Avg(10):   132.10 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  115/200 | Reward:    38.05 | Avg(10):   131.53 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  116/200 | Reward:   220.01 | Avg(10):   131.03 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  117/200 | Reward:   175.42 | Avg(10):   130.64 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  118/200 | Reward:   133.09 | Avg(10):   130.89 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  119/200 | Reward:    89.00 | Avg(10):   130.92 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  120/200 | Reward:    44.74 | Avg(10):   131.12 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  121/200 | Reward:   221.78 | Avg(10):   131.48 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  122/200 | Reward:   173.25 | Avg(10):   131.59 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  123/200 | Reward:   127.12 | Avg(10):   131.09 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  124/200 | Reward:    87.78 | Avg(10):   131.02 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  125/200 | Reward:    41.03 | Avg(10):   131.32 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  126/200 | Reward:   225.88 | Avg(10):   131.91 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  127/200 | Reward:   178.93 | Avg(10):   132.26 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  128/200 | Reward:   133.73 | Avg(10):   132.32 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  129/200 | Reward:    89.04 | Avg(10):   132.33 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  130/200 | Reward:    42.54 | Avg(10):   132.11 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  131/200 | Reward:   226.02 | Avg(10):   132.53 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  132/200 | Reward:   177.14 | Avg(10):   132.92 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  133/200 | Reward:   130.27 | Avg(10):   133.24 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  134/200 | Reward:    88.38 | Avg(10):   133.30 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  135/200 | Reward:    41.12 | Avg(10):   133.31 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  136/200 | Reward:   227.23 | Avg(10):   133.44 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  137/200 | Reward:   173.41 | Avg(10):   132.89 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  138/200 | Reward:   133.85 | Avg(10):   132.90 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  139/200 | Reward:    87.34 | Avg(10):   132.73 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  140/200 | Reward:    43.23 | Avg(10):   132.80 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  141/200 | Reward:   223.53 | Avg(10):   132.55 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  142/200 | Reward:   177.64 | Avg(10):   132.60 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  143/200 | Reward:   130.10 | Avg(10):   132.58 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  144/200 | Reward:    86.29 | Avg(10):   132.37 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  145/200 | Reward:    43.56 | Avg(10):   132.62 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  146/200 | Reward:   223.26 | Avg(10):   132.22 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  147/200 | Reward:   169.20 | Avg(10):   131.80 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  148/200 | Reward:   132.07 | Avg(10):   131.62 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  149/200 | Reward:    85.86 | Avg(10):   131.47 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  150/200 | Reward:    43.73 | Avg(10):   131.52 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  151/200 | Reward:   224.74 | Avg(10):   131.65 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  152/200 | Reward:   174.02 | Avg(10):   131.28 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  153/200 | Reward:   131.17 | Avg(10):   131.39 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  154/200 | Reward:    86.07 | Avg(10):   131.37 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  155/200 | Reward:    44.38 | Avg(10):   131.45 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  156/200 | Reward:   221.01 | Avg(10):   131.23 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  157/200 | Reward:   174.54 | Avg(10):   131.76 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  158/200 | Reward:   133.87 | Avg(10):   131.94 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  159/200 | Reward:    88.50 | Avg(10):   132.20 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  160/200 | Reward:    42.34 | Avg(10):   132.06 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  161/200 | Reward:   225.11 | Avg(10):   132.10 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  162/200 | Reward:   175.24 | Avg(10):   132.22 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  163/200 | Reward:   130.77 | Avg(10):   132.18 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  164/200 | Reward:    86.89 | Avg(10):   132.26 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  165/200 | Reward:    42.93 | Avg(10):   132.12 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  166/200 | Reward:   225.33 | Avg(10):   132.55 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  167/200 | Reward:   175.09 | Avg(10):   132.61 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  168/200 | Reward:   133.60 | Avg(10):   132.58 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  169/200 | Reward:    88.41 | Avg(10):   132.57 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  170/200 | Reward:    42.97 | Avg(10):   132.63 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  171/200 | Reward:   224.77 | Avg(10):   132.60 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  172/200 | Reward:   179.31 | Avg(10):   133.01 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  173/200 | Reward:   133.03 | Avg(10):   133.23 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  174/200 | Reward:    88.48 | Avg(10):   133.39 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  175/200 | Reward:    43.97 | Avg(10):   133.50 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  176/200 | Reward:   227.48 | Avg(10):   133.71 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  177/200 | Reward:   179.24 | Avg(10):   134.13 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  178/200 | Reward:   133.41 | Avg(10):   134.11 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  179/200 | Reward:    87.05 | Avg(10):   133.97 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  180/200 | Reward:    44.08 | Avg(10):   134.08 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  181/200 | Reward:   218.38 | Avg(10):   133.44 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  182/200 | Reward:   178.86 | Avg(10):   133.40 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  183/200 | Reward:   126.22 | Avg(10):   132.72 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  184/200 | Reward:    87.60 | Avg(10):   132.63 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  185/200 | Reward:    45.38 | Avg(10):   132.77 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  186/200 | Reward:   226.23 | Avg(10):   132.64 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  187/200 | Reward:   179.25 | Avg(10):   132.65 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  188/200 | Reward:   130.42 | Avg(10):   132.35 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  189/200 | Reward:    86.39 | Avg(10):   132.28 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  190/200 | Reward:    44.26 | Avg(10):   132.30 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  191/200 | Reward:   226.72 | Avg(10):   133.13 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  192/200 | Reward:   181.30 | Avg(10):   133.38 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  193/200 | Reward:   132.79 | Avg(10):   134.03 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  194/200 | Reward:    87.93 | Avg(10):   134.07 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  195/200 | Reward:    45.31 | Avg(10):   134.06 | Steps:   73
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  196/200 | Reward:   228.16 | Avg(10):   134.25 | Steps:  364
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  197/200 | Reward:   177.25 | Avg(10):   134.05 | Steps:  292
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  198/200 | Reward:   131.93 | Avg(10):   134.20 | Steps:  219
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  199/200 | Reward:    88.32 | Avg(10):   134.40 | Steps:  146
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
# Episode  200/200 | Reward:    44.78 | Avg(10):   134.45 | Steps:   73
#
# Training complete!
#   Final avg reward (last 10): 134.4494
#   Action distribution: {'no_action': 15675, 'partial_update': 3590, 'full_retrain': 2810, 'alert': 17085, 'switch_model': 4600}
#
# States visited      : 127
# Preferences learned : 127
# Final temperature   : 0.7339

# %%
agent.save(os.path.join(PROJECT_ROOT,'RL-concept-drift', 'experiments', 'results', 'mc_agent.pkl'))
# Out:
# [MCAgent] Saved → /kaggle/working/RL-concept-drift/experiments/results/mc_agent.pkl

# %% [markdown]
# ## 4. Learning Curve (Training Phase)

# %%
plot_cumulative_reward(
    {'MC Agent': training_history['episode_rewards']},
    title    = 'MC Agent – Episode Reward (Train Stream)',
    filename = 'mc_learning_curve.png',
)

# Quick stats
rewards = training_history['episode_rewards']
print(f'Episodes           : {len(rewards)}')
print(f'Avg reward (all)   : {np.mean(rewards):.4f}')
print(f'Avg reward (last10): {np.mean(rewards[-10:]):.4f}')
print(f'Best episode       : {max(rewards):.4f}')
# Out:
# [Visualizer] Saved → /kaggle/working/RL-concept-drift/experiments/results/mc_learning_curve.png
# Episodes           : 200
# Avg reward (all)   : 129.9156
# Avg reward (last10): 134.4494
# Best episode       : 228.1650

# %% [markdown]
# ## 5. Warm-up – Căn chỉnh tất cả Models trước khi Evaluate
#
# Trước khi vào test stream, ta retrain **tất cả models** ( Static clf, Periodic clf, Always clf)
# trên `FULL_WINDOW_BATCHES` batches cuối của train stream.
#
# **Lý do:** Đây là điểm khởi đầu công bằng – tất cả strategies bắt đầu test stream
# với model được train trên cùng một đoạn data gần nhất.

# %%
# Lấy FULL_WINDOW_BATCHES batches cuối train stream
X_warm, y_warm = loader.get_warmup_data(n_batches=FULL_WINDOW_BATCHES)
print(f'Warm-up data shape : {X_warm.shape}')
print(f'({FULL_WINDOW_BATCHES} batches × {BATCH_SIZE} samples = {FULL_WINDOW_BATCHES*BATCH_SIZE:,} samples)')

# Warm-up tất cả classifiers
def warmup_clf(name: str) -> LightGBM:
    """Tạo fresh clf, train thẳng trên X_warm (FULL_WINDOW_BATCHES batches cuối train stream)."""
    warmed = LightGBM()
    warmed.full_retrain(X_warm, y_warm)
    print(f'  [{name}] Warmed up on {len(X_warm):,} samples')
    return warmed

# MC Agent clf (đang là state sau episode cuối của training)
# → retrain lại trên warm-up để đồng bộ với baselines
print('Warming up all classifiers...')
clf_static        = warmup_clf('Static')
clf_periodic      = warmup_clf('Periodic')
clf_always        = warmup_clf('Always')
clf_warmed_mc     = warmup_clf('MC Agent')

print('\nAll models warmed up. Ready to evaluate on test stream.')
# Out:
# Warm-up data shape : (10000, 7)
# (10 batches × 1000 samples = 10,000 samples)
#
# Warming up all classifiers...
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
#   [Static] Warmed up on 10,000 samples
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
#   [Periodic] Warmed up on 10,000 samples
# [Classifier] Training on 20,000 samples...
# [Classifier] Training complete.
#   [Always] Warmed up on 10,000 samples
#
# All models warmed up. Ready to evaluate on test stream.

# %% [markdown]
# ## 6. Phase 2 – Evaluate trên Test Stream
#
# ### 6a. MC Agent (Learned Policy)
#
# `env.reset(mode="test")` → `stream_test_batches()` → batch {n_train} đến {n_total-1}.
# Agent dùng learned policy, **không gọi `agent.update()`**, không decay epsilon.

# %%
def evaluate_mc_agent(agent: MCAgent, env: DriftStreamEnv, n_episodes: int = 3, warm_model = None) -> dict:
    """
    Prequential evaluation của MC Agent trên test stream.

    - mode='test' → stream_test_batches(), không skip, không decay epsilon
    - Agent act theo learned policy (temperature đã decay về MC_TEMP_END)
    - KHÔNG update H, G_bar (no learning)
    - n_episodes > 1 để average qua stochasticity của policy
    """
    print(f'\n=== Evaluating MC Agent on TEST stream ({n_episodes} episodes) ===')

    all_preq_acc    = []
    all_rolling_err = []
    all_drift       = []
    all_uncertainty = []
    all_rewards     = []
    all_actions     = []
    all_retrain_events  = []

    for ep in range(n_episodes):
        # mode='test' → stream_test_batches, không decay epsilon
        state     = env.reset(start_batch=0, mode='test', warm_model=warm_model)
        ep_reward = 0.0
        step      = 0
        ep_retrain_events = []
        ep_actions = []

        while not env.is_done:
            action, pi = agent.select_action(state)

            # update_explorer=False: không update GradientBandit
            next_state, reward, done, info = env.step(
                action,current_state=state, pi=pi, update_explorer=False
            )

            if done and 'action_taken' not in info:
                break

            ep_reward += reward
            ep_actions.append(info['action_taken'])

            if info['action_taken'] in ['partial_update', 'full_retrain']:
                ep_retrain_events.append(info['batch_idx'])

            step  += 1
            state  = next_state
        all_retrain_events.append(ep_retrain_events)
        all_actions.append(ep_actions)

        all_rewards.append(ep_reward)
        all_preq_acc.append(env.metrics.prequential_acc_history.copy())
        all_rolling_err.append(env.metrics.rolling_error_history.copy())
        all_drift.append(env.metrics.drift_measure_history.copy())
        all_uncertainty.append(env.metrics.uncertainty_history.copy())
        print(f'  Episode {ep+1}: reward={ep_reward:.2f}, steps={step}')
    retrain_events = all_retrain_events[-1]

    # Average qua các episodes
    min_len         = min(len(h) for h in all_preq_acc)
    avg_preq_acc    = np.mean([h[:min_len] for h in all_preq_acc],    axis=0).tolist()
    avg_rolling_err = np.mean([h[:min_len] for h in all_rolling_err], axis=0).tolist()
    avg_drift       = np.mean([h[:min_len] for h in all_drift],       axis=0).tolist()
    avg_uncertainty = np.mean([h[:min_len] for h in all_uncertainty], axis=0).tolist()

    action_dist = {}
    action_dist = {}
    for ep_actions in all_actions:
        for a in ep_actions:
            action_dist[a] = action_dist.get(a, 0) + 1
    for k in action_dist:
        action_dist[k] = round(action_dist[k] / n_episodes, 1)

    print(f'\n  Avg reward     : {np.mean(all_rewards):.4f} ± {np.std(all_rewards):.4f}')
    print(f'  Final preq acc : {avg_preq_acc[-1]:.4f}')
    print(f'  Final roll err : {avg_rolling_err[-1]:.4f}')
    print(f'  Action dist    : {action_dist}')
    print(f'  Retrain events : {len(retrain_events)}')

    return {
        'label'          : 'MC Agent',
        'prequential_acc': avg_preq_acc,
        'rolling_error'  : avg_rolling_err,
        'drift_measure'  : avg_drift,
        'uncertainty'    : avg_uncertainty,
        'episode_rewards': all_rewards,
        'action_dist'    : action_dist,
        'retrain_events' : retrain_events,
        'avg_retrains'   : np.mean([len(e) for e in all_retrain_events]),
        'final_summary'  : {
            'prequential_accuracy': avg_preq_acc[-1],
            'rolling_error'       : avg_rolling_err[-1],
            'n_retrains'          : len(retrain_events),
        },
    }
clf_warmed_mc = warmup_clf(env.clf, X_warm, y_warm, 'MC_agent')
results_mc = evaluate_mc_agent(agent, env, n_episodes=3, warm_model= clf_warmed_mc)
# Out:
#   [MC_agent] Warmed up on 10,000 samples
#
# === Evaluating MC Agent on TEST stream (3 episodes) ===
#   Episode 1: reward=95.32, steps=157
#   Episode 2: reward=93.23, steps=157
#   Episode 3: reward=95.96, steps=157
#
#   Avg reward     : 94.8377 ± 1.1642
#   Final preq acc : 0.6260
#   Final roll err : 0.4180
#   Action dist    : {'partial_update': 5.3, 'alert': 74.7, 'no_action': 66.3, 'full_retrain': 5.7, 'switch_model': 5.0}
#   Retrain events : 11

# %% [markdown]
# ### 6b. Baselines trên Test Stream

# %%
def run_baseline_test(strategy: str, clf_warmed: LightGBM,
                      retrain_every: int = 50) -> dict:
    """
    Chạy baseline strategy trên TEST stream.

    Args:
        strategy   : 'static' | 'periodic' | 'always'
        clf_warmed : classifier đã được warm-up (cùng data với MC Agent)
        retrain_every: chu kỳ retrain cho periodic (tính theo batch index test stream)
    """
    print(f'\n=== Baseline: {strategy.upper()} (test stream) ===')

    clf            = copy.deepcopy(clf_warmed)
    metrics        = StreamMetrics()
    window_buffer  = deque(maxlen=FULL_WINDOW_BATCHES)
    retrain_events = []

    # Set reference từ warm-up data
    fold_size   = len(X_warm) // 5
    init_errors = [
        clf.get_error_rate(
            X_warm.iloc[i*fold_size:(i+1)*fold_size],
            y_warm.iloc[i*fold_size:(i+1)*fold_size]
        ) for i in range(5)
    ]
    metrics.set_reference(init_errors)

    batch_count = 0   # local counter trong test stream

    for X_batch, y_batch, idx in loader.stream_test_batches():
        window_buffer.append((X_batch, y_batch))

        preds      = clf.predict(X_batch)
        y_proba    = clf.predict_proba(X_batch)
        error_rate = clf.get_error_rate(X_batch, y_batch)
        metrics.update(y_batch.values, preds, error_rate, y_proba)


        if strategy == 'periodic' and batch_count > 0 and batch_count % retrain_every == 0:
            recent = list(window_buffer)
            X_w = pd.concat([b[0] for b in recent], ignore_index=True)
            y_w = pd.concat([b[1] for b in recent], ignore_index=True)
            for col in CATEGORICAL_COLS:
                X_w[col] = X_w[col].astype('category')
            clf.full_retrain(X_w, y_w)
            retrain_events.append(idx)

        elif strategy == 'always':
            recent = list(window_buffer)
            X_w = pd.concat([b[0] for b in recent], ignore_index=True)
            y_w = pd.concat([b[1] for b in recent], ignore_index=True)
            for col in CATEGORICAL_COLS:
                X_w[col] = X_w[col].astype('category')
            clf.full_retrain(X_w, y_w)
            retrain_events.append(idx)

        
        batch_count += 1

    print(f'  Done! Batches: {batch_count}, Retrains: {len(retrain_events)}')
    return {
        'label'          : strategy,
        'prequential_acc': metrics.prequential_acc_history,
        'rolling_error'  : metrics.rolling_error_history,
        'drift_measure'  : metrics.drift_measure_history,
        'uncertainty'    : metrics.uncertainty_history,
        'retrain_events' : retrain_events,
        'final_summary'  : metrics.summary(),
    }

results_static   = run_baseline_test('static',   clf_static)
results_periodic = run_baseline_test('periodic', clf_periodic, retrain_every=50)
results_always   = run_baseline_test('always',   clf_always)
# Out:
# === Baseline: STATIC (test stream) ===
#   Done! Batches: 156, Retrains: 0
#
# === Baseline: PERIODIC (test stream) ===
#   Done! Batches: 156, Retrains: 3
#
# === Baseline: ALWAYS (test stream) ===
#   Done! Batches: 156, Retrains: 156

# %% [markdown]
# ## 7. Summary Table

# %%
print('\n' + '='*70)
print(f"{'Strategy':<20} {'Preq Acc':>10} {'Roll Err':>10} {'Retrains':>10}")
print('='*70)

for name, results in [
    ('Static',   results_static),
    ('Periodic', results_periodic),
    ('Always',   results_always),
    ('MC Agent', results_mc),
]:
    preq = results['prequential_acc'][-1]
    err  = results['rolling_error'][-1]
    if name == 'MC Agent':
        n_rt = round(results['avg_retrains'])
    else:
        n_rt = len(results['retrain_events'])
    marker = ' ←' if name == 'MC Agent' else ''
    print(f"{name:<20} {preq:>10.4f} {err:>10.4f} {n_rt:>10}{marker}")

print('='*70)
print('* Tất cả strategies evaluate trên test stream (30% cuối).')
print(f'* Warm-up: {FULL_WINDOW_BATCHES} batches cuối train stream (điểm khởi đầu công bằng).')
# Out:
# ======================================================================
# Strategy               Preq Acc   Roll Err   Retrains
# ======================================================================
# Static                   0.5951     0.3880          0
# Periodic                 0.6005     0.3920          3
# Always                   0.6710     0.3700        156
# MC Agent                 0.6260     0.4180         11 ←
# ======================================================================
# * Tất cả strategies evaluate trên test stream (30% cuối).
# * Warm-up: 10 batches cuối train stream (điểm khởi đầu công bằng).

# %%
print(results_mc['action_dist'])
# Out:
# {'partial_update': 5.3, 'alert': 74.7, 'no_action': 66.3, 'full_retrain': 5.7, 'switch_model': 5.0}

# %% [markdown]
# ## 8. Learning Curve (Training Phase)

# %%
plot_cumulative_reward(
    {'MC Agent': training_history['episode_rewards']},
    title    = 'MC Agent – Episode Reward over Training (Train Stream)',
    filename = 'mc_learning_curve.png',
)
# Out:
# [Visualizer] Saved → /kaggle/working/RL-concept-drift/experiments/results/mc_learning_curve.png

# %% [markdown]
# ## 9. MC Agent Dashboard (Test Stream)

# %%
plot_dashboard(
    results_mc,
    title    = 'MC Agent – Stream Metrics Dashboard (Test Stream)',
    filename = 'mc_dashboard.png',
)
# Out:
# [Visualizer] Saved → /kaggle/working/RL-concept-drift/experiments/results/mc_dashboard.png
# /kaggle/working/RL-concept-drift/utils/visualizer.py:54: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# ## 10. MC Agent vs Baselines (Test Stream)

# %%
plot_agent_vs_baselines(
    baselines = {
        'Static'  : results_static['prequential_acc'],
        'Periodic': results_periodic['prequential_acc'],
        'Always'  : results_always['prequential_acc'],
    },
    agents   = {'MC Agent': results_mc['prequential_acc']},
    ylabel   = 'Prequential Accuracy',
    title    = 'MC Agent vs Baselines – Prequential Accuracy (Test Stream)',
    filename = 'mc_vs_baselines_acc.png',
)

plot_agent_vs_baselines(
    baselines = {
        'Static'  : results_static['rolling_error'],
        'Periodic': results_periodic['rolling_error'],
        'Always'  : results_always['rolling_error'],
    },
    agents   = {'MC Agent': results_mc['rolling_error']},
    ylabel   = 'Rolling Error Rate',
    title    = 'MC Agent vs Baselines – Rolling Error Rate (Test Stream)',
    filename = 'mc_vs_baselines_err.png',
)
# Out:
# [Visualizer] Saved → /kaggle/working/RL-concept-drift/experiments/results/mc_vs_baselines_acc.png
# [Visualizer] Saved → /kaggle/working/RL-concept-drift/experiments/results/mc_vs_baselines_err.png

# %% [markdown]
# ## 11. Action Distribution (Test Stream)

# %%
plot_action_distribution(
    {'MC Agent': results_mc['action_dist']},
    title    = 'MC Agent – Action Distribution (Test Stream)',
    filename = 'mc_action_dist.png',
)

print('\nAction counts (test stream, averaged over 3 episodes):')
total = sum(results_mc['action_dist'].values())
for action, count in sorted(results_mc['action_dist'].items(), key=lambda x: -x[1]):
    print(f'  {action:<16}: {count:>5}  ({100*count/total:.1f}%)')
# Out:
# [Visualizer] Saved → /kaggle/working/RL-concept-drift/experiments/results/mc_action_dist.png
# Action counts (test stream, averaged over 3 episodes):
#   alert           :  74.7  (47.6%)
#   no_action       :  66.3  (42.2%)
#   full_retrain    :   5.7  (3.6%)
#   partial_update  :   5.3  (3.4%)
#   switch_model    :   5.0  (3.2%)

# %% [markdown]
# ## 12. Retrain Events (Test Stream)

# %%
plot_retrain_events(
    results_mc['rolling_error'],
    results_mc['retrain_events'],
    title    = 'MC Agent – Rolling Error + Retrain Events (Test Stream)',
    filename = 'mc_retrain_events.png',
)
# Out:
# [Visualizer] Saved → /kaggle/working/RL-concept-drift/experiments/results/mc_retrain_events.png

# %% [markdown]
# ## 13. Observations
#
# **Setup:**
# - Train stream: batch 0–{n_train-1} ({train_pct}% data stream)
# - Test stream : batch {n_train}–{n_total-1} ({test_pct}% data stream)
# - Warm-up     : `FULL_WINDOW_BATCHES` batches cuối train stream → điểm khởi đầu công bằng
#
# **Câu hỏi cần trả lời sau khi chạy:**
#
# *Learning curve:*
# - Reward có tăng dần qua 200 episodes không?
# - Bao nhiêu episodes để bắt đầu hội tụ?
# - Temperature decay có ảnh hưởng rõ đến exploration/exploitation không?
#
# *So sánh test stream:*
# - MC Agent prequential accuracy vs Static / Periodic / Always?
# - MC Agent rolling error thấp hơn Static không?
# - Số lần retrain của MC Agent so với Periodic (mỗi 50 batches)?
# - MC Agent có efficient hơn Always (ít retrain hơn nhưng accuracy tương đương)?
#
# *Action distribution:*
# - Agent có học được khi nào nên retrain không?
# - Tỷ lệ `no_action` vs `full_retrain` vs `partial_update`?
# - Agent có dùng `alert` và `switch_model` không?
#
# → Nếu kết quả tốt: tăng lên 500 episodes, giảm temperature decay chậm hơn.
# → Nếu chưa tốt: kiểm tra reward function, action costs, drift measure (thử đổi PSI → ADWIN).
